# %%
with open("info.txt", 'r') as file:
    for line in file:
        (name, weight, height) = line.split(',')

        if(not name) or (not weight) or (not height):
            continue
        bmi = int(weight) / (int(height) ** 2)
        result = ""
        if 25 <= bmi:
            result = "과체중"
        elif 18.5 <= bmi:
            result = "정상 체중"
        else:
            result = "저체중"

        print('\n'.join([
            "이름 : {}",
            "몸무게 : {}",
            "키 : {}",
            "BMI : {}",
            "결과 : {}"
        ]).format(name, weight, height, bmi, result))
        print()
# Out:
# 이름 : 가파
# 몸무게 :  50
# 키 :  163
#
# BMI : 0.0018818924310286425
# 결과 : 저체중
#
# 이름 : 하나
# 몸무게 :  43
# 키 :  181
#
# BMI : 0.0013125362473672966
# 결과 : 저체중
#
# 이름 : 파타
# 몸무게 :  72
# 키 :  197
#
# BMI : 0.0018552397639722744
# 결과 : 저체중
#
# 이름 : 바차
# 몸무게 :  89
# 키 :  196
#
# BMI : 0.0023167430237401084
# 결과 : 저체중
#
# 이름 : 하파
# 몸무게 :  90
# 키 :  150
#
# BMI : 0.004
# 결과 : 저체중
#
# 이름 : 가가
# 몸무게 :  87
# 키 :  198
#
# BMI : 0.002219161310070401
# 결과 : 저체중
#
# 이름 : 하가
# 몸무게 :  76
# 키 :  182
#
# BMI : 0.0022944088878154812
# 결과 : 저체중
#
# 이름 : 바라
# 몸무게 :  85
# 키 :  186
#
# BMI : 0.0024569314371603655
# 결과 : 저체중
#
# 이름 : 라라
# 몸무게 :  97
# 키 :  183
#
# BMI : 0.002896473468900236
# 결과 : 저체중
#
# 이름 : 가하
# 몸무게 :  47
# 키 :  168
#
# BMI : 0.001665249433106576
# 결과 : 저체중
#
# 이름 : 사아
# 몸무게 :  90
# 키 :  140
#
# BMI : 0.004591836734693878
# 결과 : 저체중
#
# 이름 : 파아
# 몸무게 :  59
# 키 :  141
#
# BMI : 0.0029676575624968562
# 결과 : 저체중
#
# 이름 : 타가
# 몸무게 :  70
# 키 :  171
#
# BMI : 0.002393898977463151
# 결과 : 저체중
#
# 이름 : 카바
# 몸무게 :  96
# 키 :  196
#
# BMI : 0.0024989587671803417
# 결과 : 저체중
#
# 이름 : 라카
# 몸무게 :  68
# 키 :  141
#
# BMI : 0.0034203510889794274
# 결과 : 저체중
#
# 이름 : 라아
# 몸무게 :  99
# 키 :  145
#
# BMI : 0.004708680142687277
# 결과 : 저체중
#
# 이름 : 가하
# 몸무게 :  67
# 키 :  144
#
# BMI : 0.0032310956790123457
# 결과 : 저체중
#
# 이름 : 카다
# 몸무게 :  51
# 키 :  198
#
# BMI : 0.0013008876645240282
# 결과 : 저체중
#
# 이름 : 차다
# 몸무게 :  72
# 키 :  145
#
# BMI : 0.0034244946492271106
# 결과 : 저체중
#
# 이름 : 차다
# 몸무게 :  48
# 키 :  159
#
# BMI : 0.0018986590720303786
# 결과 : 저체중
#
# 이름 : 가다
# 몸무게 :  53
# 키 :  140
#
# BMI : 0.002704081632653061
# 결과 : 저체중
#
# 이름 : 타마
# 몸무게 :  72
# 키 :  157
#
# BMI : 0.002921010994360826
# 결과 : 저체중
#
# 이름 : 자다
# 몸무게 :  41
# 키 :  199
#
# BMI : 0.0010353273907224565
# 결과 : 저체중
#
# 이름 : 차타
# 몸무게 :  80
# 키 :  150
#
# BMI : 0.0035555555555555557
# 결과 : 저체중
#
# 이름 : 가타
# 몸무게 :  70
# 키 :  184
#
# BMI : 0.00206758034026465
# 결과 : 저체중
#
# 이름 : 자자
# 몸무게 :  74
# 키 :  175
#
# BMI : 0.002416326530612245
# 결과 : 저체중
#
# 이름 : 가파
# 몸무게 :  51
# 키 :  157
#
# BMI : 0.0020690494543389184
# 결과 : 저체중
#
# 이름 : 바자
# 몸무게 :  95
# 키 :  167
#
# BMI : 0.0034063609308329448
# 결과 : 저체중
#
# 이름 : 다아
# 몸무게 :  61
# 키 :  169
#
# BMI : 0.0021357795595392318
# 결과 : 저체중
#
# 이름 : 파라
# 몸무게 :  40
# 키 :  141
#
# BMI : 0.002011971228811428
# 결과 : 저체중
#
# 이름 : 파파
# 몸무게 :  95
# 키 :  164
#
# BMI : 0.003532123735871505
# 결과 : 저체중
#
# 이름 : 카파
# 몸무게 :  53
# 키 :  190
#
# BMI : 0.0014681440443213296
# 결과 : 저체중
#
# 이름 : 바사
# 몸무게 :  55
# 키 :  171
#
# BMI : 0.0018809206251496186
# 결과 : 저체중
#
# 이름 : 라가
# 몸무게 :  65
# 키 :  171
#
# BMI : 0.00222290619335864
# 결과 : 저체중
#
# 이름 : 타차
# 몸무게 :  78
# 키 :  145
#
# BMI : 0.0037098692033293696
# 결과 : 저체중
#
# 이름 : 라타
# 몸무게 :  92
# 키 :  161
#
# BMI : 0.00354924578527063
# 결과 : 저체중
#
# 이름 : 마카
# 몸무게 :  68
# 키 :  183
#
# BMI : 0.0020305174833527427
# 결과 : 저체중
#
# 이름 : 자바
# 몸무게 :  53
# 키 :  188
#
# BMI : 0.0014995473064735175
# 결과 : 저체중
#
# 이름 : 가파
# 몸무게 :  48
# 키 :  194
#
# BMI : 0.001275374641300882
# 결과 : 저체중
#
# 이름 : 아사
# 몸무게 :  78
# 키 :  194
#
# BMI : 0.0020724837921139334
# 결과 : 저체중
#
# 이름 : 자하
# 몸무게 :  87
# 키 :  153
#
# BMI : 0.0037165192874535433
# 결과 : 저체중
#
# 이름 : 사다
# 몸무게 :  62
# 키 :  181
#
# BMI : 0.0018924941241109856
# 결과 : 저체중
#
# 이름 : 차파
# 몸무게 :  66
# 키 :  178
#
# BMI : 0.002083070319404116
# 결과 : 저체중
#
# 이름 : 라차
# 몸무게 :  72
# 키 :  162
#
# BMI : 0.0027434842249657062
# 결과 : 저체중
#
# 이름 : 파카
# 몸무게 :  64
# 키 :  167
#
# BMI : 0.0022948115744558786
# 결과 : 저체중
#
# 이름 : 나다
# 몸무게 :  82
# 키 :  149
#
# BMI : 0.003693527318589253
# 결과 : 저체중
#
# 이름 : 가아
# 몸무게 :  49
# 키 :  171
#
# BMI : 0.0016757292842242057
# 결과 : 저체중
#
# 이름 : 하차
# 몸무게 :  91
# 키 :  192
#
# BMI : 0.002468532986111111
# 결과 : 저체중
#
# 이름 : 사카
# 몸무게 :  90
# 키 :  177
#
# BMI : 0.002872737719046251
# 결과 : 저체중
#
# 이름 : 다차
# 몸무게 :  69
# 키 :  197
#
# BMI : 0.0017779381071400964
# 결과 : 저체중
#
# 이름 : 하자
# 몸무게 :  95
# 키 :  162
#
# BMI : 0.003619875019051974
# 결과 : 저체중
#
# 이름 : 자카
# 몸무게 :  82
# 키 :  156
#
# BMI : 0.0033694937541091387
# 결과 : 저체중
#
# 이름 : 라가
# 몸무게 :  94
# 키 :  152
#
# BMI : 0.004068559556786704
# 결과 : 저체중
#
# 이름 : 가라
# 몸무게 :  51
# 키 :  190
#
# BMI : 0.0014127423822714682
# 결과 : 저체중
#
# 이름 : 마아
# 몸무게 :  40
# 키 :  161
#
# BMI : 0.0015431503414220131
# 결과 : 저체중
#
# 이름 : 타하
# 몸무게 :  86
# 키 :  156
#
# BMI : 0.0035338593030900724
# 결과 : 저체중
#
# 이름 : 타타
# 몸무게 :  58
# 키 :  150
#
# BMI : 0.002577777777777778
# 결과 : 저체중
#
# 이름 : 다하
# 몸무게 :  64
# 키 :  192
#
# BMI : 0.001736111111111111
# 결과 : 저체중
#
# 이름 : 라아
# 몸무게 :  59
# 키 :  161
#
# BMI : 0.0022761467535974693
# 결과 : 저체중
#
# 이름 : 다마
# 몸무게 :  95
# 키 :  199
#
# BMI : 0.0023989293199666675
# 결과 : 저체중
#
# 이름 : 다다
# 몸무게 :  68
# 키 :  152
#
# BMI : 0.002943213296398892
# 결과 : 저체중
#
# 이름 : 다타
# 몸무게 :  70
# 키 :  195
#
# BMI : 0.0018408941485864563
# 결과 : 저체중
#
# 이름 : 하카
# 몸무게 :  40
# 키 :  155
#
# BMI : 0.0016649323621227888
# 결과 : 저체중
#
# 이름 : 사라
# 몸무게 :  56
# 키 :  149
#
# BMI : 0.0025224089004999774
# 결과 : 저체중
#
# 이름 : 가차
# 몸무게 :  83
# 키 :  161
#
# BMI : 0.003202036958450677
# 결과 : 저체중
#
# 이름 : 바마
# 몸무게 :  51
# 키 :  156
#
# BMI : 0.002095660749506903
# 결과 : 저체중
#
# 이름 : 타아
# 몸무게 :  44
# 키 :  178
#
# BMI : 0.0013887135462694105
# 결과 : 저체중
#
# 이름 : 바파
# 몸무게 :  78
# 키 :  183
#
# BMI : 0.002329122995610499
# 결과 : 저체중
#
# 이름 : 타가
# 몸무게 :  78
# 키 :  156
#
# BMI : 0.003205128205128205
# 결과 : 저체중
#
# 이름 : 하타
# 몸무게 :  78
# 키 :  173
#
# BMI : 0.002606167930769488
# 결과 : 저체중
#
# 이름 : 파나
# 몸무게 :  92
# 키 :  157
#
# BMI : 0.003732402937238833
# 결과 : 저체중
#
# 이름 : 하다
# 몸무게 :  93
# 키 :  187
#
# BMI : 0.0026594984128799795
# 결과 : 저체중
#
# 이름 : 파다
# 몸무게 :  98
# 키 :  181
#
# BMI : 0.0029913616800463965
# 결과 : 저체중
#
# 이름 : 라타
# 몸무게 :  92
# 키 :  185
#
# BMI : 0.0026880934989043097
# 결과 : 저체중
#
# 이름 : 마나
# 몸무게 :  96
# 키 :  158
#
# BMI : 0.0038455375741067136
# 결과 : 저체중
#
# 이름 : 아가
# 몸무게 :  70
# 키 :  142
#
# BMI : 0.003471533425907558
# 결과 : 저체중
#
# 이름 : 마사
# 몸무게 :  67
# 키 :  169
#
# BMI : 0.0023458562375266974
# 결과 : 저체중
#
# 이름 : 사타
# 몸무게 :  61
# 키 :  181
#
# BMI : 0.001861970025335002
# 결과 : 저체중
#
# 이름 : 차사
# 몸무게 :  89
# 키 :  183
#
# BMI : 0.002657589059094031
# 결과 : 저체중
#
# 이름 : 바다
# 몸무게 :  55
# 키 :  180
#
# BMI : 0.0016975308641975309
# 결과 : 저체중
#
# 이름 : 나차
# 몸무게 :  64
# 키 :  197
#
# BMI : 0.0016491020124197995
# 결과 : 저체중
#
# 이름 : 카하
# 몸무게 :  42
# 키 :  141
#
# BMI : 0.0021125697902519996
# 결과 : 저체중
#
# 이름 : 타가
# 몸무게 :  48
# 키 :  146
#
# BMI : 0.002251829611559392
# 결과 : 저체중
#
# 이름 : 아아
# 몸무게 :  43
# 키 :  166
#
# BMI : 0.0015604587022789954
# 결과 : 저체중
#
# 이름 : 자카
# 몸무게 :  57
# 키 :  143
#
# BMI : 0.002787422367841948
# 결과 : 저체중
#
# 이름 : 나아
# 몸무게 :  48
# 키 :  183
#
# BMI : 0.0014333064588372302
# 결과 : 저체중
#
# 이름 : 마자
# 몸무게 :  41
# 키 :  142
#
# BMI : 0.0020333267208887127
# 결과 : 저체중
#
# 이름 : 차다
# 몸무게 :  46
# 키 :  156
#
# BMI : 0.0018902038132807364
# 결과 : 저체중
#
# 이름 : 카아
# 몸무게 :  45
# 키 :  154
#
# BMI : 0.0018974531961544949
# 결과 : 저체중
#
# 이름 : 가하
# 몸무게 :  59
# 키 :  162
#
# BMI : 0.0022481329065691205
# 결과 : 저체중
#
# 이름 : 사자
# 몸무게 :  69
# 키 :  176
#
# BMI : 0.002227530991735537
# 결과 : 저체중
#
# 이름 : 마다
# 몸무게 :  88
# 키 :  163
#
# BMI : 0.0033121306786104104
# 결과 : 저체중
#
# 이름 : 차차
# 몸무게 :  49
# 키 :  197
#
# BMI : 0.001262593728258909
# 결과 : 저체중
#
# 이름 : 타자
# 몸무게 :  65
# 키 :  186
#
# BMI : 0.001878829922534397
# 결과 : 저체중
#
# 이름 : 타마
# 몸무게 :  52
# 키 :  181
#
# BMI : 0.0015872531363511492
# 결과 : 저체중
#
# 이름 : 나자
# 몸무게 :  56
# 키 :  157
#
# BMI : 0.0022718974400584204
# 결과 : 저체중
#
# 이름 : 하다
# 몸무게 :  43
# 키 :  144
#
# BMI : 0.0020736882716049384
# 결과 : 저체중
#
# 이름 : 다다
# 몸무게 :  46
# 키 :  197
#
# BMI : 0.001185292071426731
# 결과 : 저체중
#
# 이름 : 카하
# 몸무게 :  58
# 키 :  149
#
# BMI : 0.002612494932660691
# 결과 : 저체중
#
# 이름 : 라나
# 몸무게 :  47
# 키 :  154
#
# BMI : 0.001981784449316917
# 결과 : 저체중
#
# 이름 : 다하
# 몸무게 :  82
# 키 :  179
#
# BMI : 0.002559220998096189
# 결과 : 저체중
#
# 이름 : 하바
# 몸무게 :  81
# 키 :  168
#
# BMI : 0.0028698979591836736
# 결과 : 저체중
#
# 이름 : 바하
# 몸무게 :  79
# 키 :  175
#
# BMI : 0.0025795918367346937
# 결과 : 저체중
#
# 이름 : 타마
# 몸무게 :  96
# 키 :  163
#
# BMI : 0.0036132334675749935
# 결과 : 저체중
#
# 이름 : 바마
# 몸무게 :  41
# 키 :  158
#
# BMI : 0.0016423650056080756
# 결과 : 저체중
#
# 이름 : 타마
# 몸무게 :  59
# 키 :  176
#
# BMI : 0.0019047004132231404
# 결과 : 저체중
#
# 이름 : 자마
# 몸무게 :  78
# 키 :  172
#
# BMI : 0.0026365603028664143
# 결과 : 저체중
#
# 이름 : 카차
# 몸무게 :  81
# 키 :  177
#
# BMI : 0.002585463947141626
# 결과 : 저체중
#
# 이름 : 바타
# 몸무게 :  95
# 키 :  179
#
# BMI : 0.002964951156330951
# 결과 : 저체중
#
# 이름 : 다차
# 몸무게 :  57
# 키 :  183
#
# BMI : 0.0017020514198692108
# 결과 : 저체중
#
# 이름 : 카바
# 몸무게 :  56
# 키 :  152
#
# BMI : 0.0024238227146814403
# 결과 : 저체중
#
# 이름 : 가가
# 몸무게 :  47
# 키 :  143
#
# BMI : 0.0022984008997995013
# 결과 : 저체중
#
# 이름 : 차가
# 몸무게 :  95
# 키 :  160
#
# BMI : 0.0037109375
# 결과 : 저체중
#
# 이름 : 가사
# 몸무게 :  64
# 키 :  156
#
# BMI : 0.0026298487836949377
# 결과 : 저체중
#
# 이름 : 가카
# 몸무게 :  80
# 키 :  189
#
# BMI : 0.002239578959155679
# 결과 : 저체중
#
# 이름 : 파바
# 몸무게 :  92
# 키 :  184
#
# BMI : 0.002717391304347826
# 결과 : 저체중
#
# 이름 : 카라
# 몸무게 :  76
# 키 :  195
#
# BMI : 0.0019986850756081526
# 결과 : 저체중
#
# 이름 : 카카
# 몸무게 :  86
# 키 :  150
#
# BMI : 0.003822222222222222
# 결과 : 저체중
#
# 이름 : 바다
# 몸무게 :  70
# 키 :  159
#
# BMI : 0.0027688778133776355
# 결과 : 저체중
#
# 이름 : 다아
# 몸무게 :  98
# 키 :  198
#
# BMI : 0.0024997449239873484
# 결과 : 저체중
#
# 이름 : 하바
# 몸무게 :  75
# 키 :  189
#
# BMI : 0.002099605274208449
# 결과 : 저체중
#
# 이름 : 라아
# 몸무게 :  80
# 키 :  199
#
# BMI : 0.00202015100628772
# 결과 : 저체중
#
# 이름 : 차바
# 몸무게 :  45
# 키 :  144
#
# BMI : 0.002170138888888889
# 결과 : 저체중
#
# 이름 : 바파
# 몸무게 :  93
# 키 :  158
#
# BMI : 0.0037253645249158787
# 결과 : 저체중
#
# 이름 : 라카
# 몸무게 :  50
# 키 :  176
#
# BMI : 0.0016141528925619835
# 결과 : 저체중
#
# 이름 : 차마
# 몸무게 :  93
# 키 :  144
#
# BMI : 0.004484953703703704
# 결과 : 저체중
#
# 이름 : 다타
# 몸무게 :  61
# 키 :  141
#
# BMI : 0.0030682561239374277
# 결과 : 저체중
#
# 이름 : 사바
# 몸무게 :  51
# 키 :  154
#
# BMI : 0.002150446955641761
# 결과 : 저체중
#
# 이름 : 차나
# 몸무게 :  46
# 키 :  199
#
# BMI : 0.0011615868286154391
# 결과 : 저체중
#
# 이름 : 가마
# 몸무게 :  86
# 키 :  153
#
# BMI : 0.0036738006749540775
# 결과 : 저체중
#
# 이름 : 라카
# 몸무게 :  65
# 키 :  150
#
# BMI : 0.0028888888888888888
# 결과 : 저체중
#
# 이름 : 하다
# 몸무게 :  57
# 키 :  149
#
# BMI : 0.0025674519165803343
# 결과 : 저체중
#
# 이름 : 타아
# 몸무게 :  52
# 키 :  152
#
# BMI : 0.0022506925207756235
# 결과 : 저체중
#
# 이름 : 바다
# 몸무게 :  93
# 키 :  189
#
# BMI : 0.0026035105400184764
# 결과 : 저체중
#
# 이름 : 카나
# 몸무게 :  45
# 키 :  154
#
# BMI : 0.0018974531961544949
# 결과 : 저체중
#
# 이름 : 차아
# 몸무게 :  77
# 키 :  194
#
# BMI : 0.0020459134870868317
# 결과 : 저체중
#
# 이름 : 마가
# 몸무게 :  47
# 키 :  183
#
# BMI : 0.0014034459076114544
# 결과 : 저체중
#
# 이름 : 하아
# 몸무게 :  41
# 키 :  149
#
# BMI : 0.0018467636592946265
# 결과 : 저체중
#
# 이름 : 다파
# 몸무게 :  65
# 키 :  149
#
# BMI : 0.0029277960452231883
# 결과 : 저체중
#
# 이름 : 파자
# 몸무게 :  47
# 키 :  188
#
# BMI : 0.0013297872340425532
# 결과 : 저체중
#
# 이름 : 하하
# 몸무게 :  94
# 키 :  187
#
# BMI : 0.002688095170007721
# 결과 : 저체중
#
# 이름 : 가마
# 몸무게 :  53
# 키 :  181
#
# BMI : 0.001617777235127133
# 결과 : 저체중
#
# 이름 : 다카
# 몸무게 :  64
# 키 :  196
#
# BMI : 0.001665972511453561
# 결과 : 저체중
#
# 이름 : 마자
# 몸무게 :  84
# 키 :  144
#
# BMI : 0.004050925925925926
# 결과 : 저체중
#
# 이름 : 자카
# 몸무게 :  85
# 키 :  174
#
# BMI : 0.0028075042938300963
# 결과 : 저체중
#
# 이름 : 다카
# 몸무게 :  71
# 키 :  157
#
# BMI : 0.0028804413972169257
# 결과 : 저체중
#
# 이름 : 바아
# 몸무게 :  82
# 키 :  168
#
# BMI : 0.002905328798185941
# 결과 : 저체중
#
# 이름 : 라타
# 몸무게 :  74
# 키 :  140
#
# BMI : 0.003775510204081633
# 결과 : 저체중
#
# 이름 : 가파
# 몸무게 :  52
# 키 :  178
#
# BMI : 0.001641206918318394
# 결과 : 저체중
#
# 이름 : 파사
# 몸무게 :  58
# 키 :  154
#
# BMI : 0.0024456063417102377
# 결과 : 저체중
#
# 이름 : 아타
# 몸무게 :  72
# 키 :  140
#
# BMI : 0.003673469387755102
# 결과 : 저체중
#
# 이름 : 다나
# 몸무게 :  97
# 키 :  187
#
# BMI : 0.002773885441390946
# 결과 : 저체중
#
# 이름 : 마다
# 몸무게 :  57
# 키 :  140
#
# BMI : 0.0029081632653061226
# 결과 : 저체중
#
# 이름 : 다다
# 몸무게 :  59
# 키 :  182
#
# BMI : 0.001781185847119913
# 결과 : 저체중
#
# 이름 : 카차
# 몸무게 :  63
# 키 :  141
#
# BMI : 0.003168854685377999
# 결과 : 저체중
#
# 이름 : 아자
# 몸무게 :  94
# 키 :  184
#
# BMI : 0.0027764650283553876
# 결과 : 저체중
#
# 이름 : 가가
# 몸무게 :  76
# 키 :  174
#
# BMI : 0.00251023913330691
# 결과 : 저체중
#
# 이름 : 하다
# 몸무게 :  98
# 키 :  158
#
# BMI : 0.003925652940233937
# 결과 : 저체중
#
# 이름 : 다자
# 몸무게 :  77
# 키 :  161
#
# BMI : 0.002970564407237375
# 결과 : 저체중
#
# 이름 : 바타
# 몸무게 :  90
# 키 :  159
#
# BMI : 0.00355998576005696
# 결과 : 저체중
#
# 이름 : 다타
# 몸무게 :  70
# 키 :  178
#
# BMI : 0.0022093170054286074
# 결과 : 저체중
#
# 이름 : 마라
# 몸무게 :  43
# 키 :  149
#
# BMI : 0.0019368496914553399
# 결과 : 저체중
#
# 이름 : 차사
# 몸무게 :  78
# 키 :  198
#
# BMI : 0.0019895928986838076
# 결과 : 저체중
#
# 이름 : 마자
# 몸무게 :  72
# 키 :  181
#
# BMI : 0.002197735111870822
# 결과 : 저체중
#
# 이름 : 자자
# 몸무게 :  90
# 키 :  183
#
# BMI : 0.0026874496103198066
# 결과 : 저체중
#
# 이름 : 파라
# 몸무게 :  69
# 키 :  195
#
# BMI : 0.001814595660749507
# 결과 : 저체중
#
# 이름 : 사아
# 몸무게 :  95
# 키 :  186
#
# BMI : 0.0027459821944733494
# 결과 : 저체중
#
# 이름 : 아아
# 몸무게 :  94
# 키 :  183
#
# BMI : 0.002806891815222909
# 결과 : 저체중
#
# 이름 : 파하
# 몸무게 :  48
# 키 :  194
#
# BMI : 0.001275374641300882
# 결과 : 저체중
#
# 이름 : 파카
# 몸무게 :  41
# 키 :  161
#
# BMI : 0.0015817290999575633
# 결과 : 저체중
#
# 이름 : 자라
# 몸무게 :  42
# 키 :  188
#
# BMI : 0.0011883205070167496
# 결과 : 저체중
#
# 이름 : 다카
# 몸무게 :  77
# 키 :  192
#
# BMI : 0.0020887586805555555
# 결과 : 저체중
#
# 이름 : 마카
# 몸무게 :  55
# 키 :  182
#
# BMI : 0.0016604274846033088
# 결과 : 저체중
#
# 이름 : 사가
# 몸무게 :  86
# 키 :  192
#
# BMI : 0.0023328993055555555
# 결과 : 저체중
#
# 이름 : 가가
# 몸무게 :  76
# 키 :  171
#
# BMI : 0.002599090318388564
# 결과 : 저체중
#
# 이름 : 하나
# 몸무게 :  61
# 키 :  148
#
# BMI : 0.0027848794740686633
# 결과 : 저체중
#
# 이름 : 바카
# 몸무게 :  75
# 키 :  197
#
# BMI : 0.0019325414208044526
# 결과 : 저체중
#
# 이름 : 나카
# 몸무게 :  74
# 키 :  154
#
# BMI : 0.0031202563670096137
# 결과 : 저체중
#
# 이름 : 파가
# 몸무게 :  85
# 키 :  183
#
# BMI : 0.0025381468541909283
# 결과 : 저체중
#
# 이름 : 가타
# 몸무게 :  85
# 키 :  178
#
# BMI : 0.0026827420780204518
# 결과 : 저체중
#
# 이름 : 가마
# 몸무게 :  99
# 키 :  148
#
# BMI : 0.004519722425127831
# 결과 : 저체중
#
# 이름 : 파다
# 몸무게 :  68
# 키 :  184
#
# BMI : 0.002008506616257089
# 결과 : 저체중
#
# 이름 : 라나
# 몸무게 :  72
# 키 :  195
#
# BMI : 0.001893491124260355
# 결과 : 저체중
#
# 이름 : 아다
# 몸무게 :  46
# 키 :  196
#
# BMI : 0.001197417742607247
# 결과 : 저체중
#
# 이름 : 마가
# 몸무게 :  68
# 키 :  172
#
# BMI : 0.002298539751216874
# 결과 : 저체중
#
# 이름 : 다타
# 몸무게 :  99
# 키 :  141
#
# BMI : 0.004979628791308284
# 결과 : 저체중
#
# 이름 : 자차
# 몸무게 :  57
# 키 :  162
#
# BMI : 0.0021719250114311845
# 결과 : 저체중
#
# 이름 : 가바
# 몸무게 :  79
# 키 :  172
#
# BMI : 0.0026703623580313684
# 결과 : 저체중
#
# 이름 : 카라
# 몸무게 :  85
# 키 :  197
#
# BMI : 0.0021902136102450462
# 결과 : 저체중
#
# 이름 : 가파
# 몸무게 :  78
# 키 :  152
#
# BMI : 0.0033760387811634348
# 결과 : 저체중
#
# 이름 : 다카
# 몸무게 :  87
# 키 :  145
#
# BMI : 0.004137931034482759
# 결과 : 저체중
#
# 이름 : 아마
# 몸무게 :  82
# 키 :  163
#
# BMI : 0.0030863035868869734
# 결과 : 저체중
#
# 이름 : 자마
# 몸무게 :  72
# 키 :  192
#
# BMI : 0.001953125
# 결과 : 저체중
#
# 이름 : 다가
# 몸무게 :  44
# 키 :  199
#
# BMI : 0.001111083053458246
# 결과 : 저체중
#
# 이름 : 차자
# 몸무게 :  55
# 키 :  178
#
# BMI : 0.001735891932836763
# 결과 : 저체중
#
# 이름 : 나나
# 몸무게 :  74
# 키 :  168
#
# BMI : 0.0026218820861678006
# 결과 : 저체중
#
# 이름 : 타바
# 몸무게 :  62
# 키 :  193
#
# BMI : 0.001664474214072861
# 결과 : 저체중
#
# 이름 : 사가
# 몸무게 :  62
# 키 :  144
#
# BMI : 0.002989969135802469
# 결과 : 저체중
#
# 이름 : 사자
# 몸무게 :  61
# 키 :  149
#
# BMI : 0.002747623980901761
# 결과 : 저체중
#
# 이름 : 카마
# 몸무게 :  85
# 키 :  197
#
# BMI : 0.0021902136102450462
# 결과 : 저체중
#
# 이름 : 나다
# 몸무게 :  56
# 키 :  186
#
# BMI : 0.0016186842409527114
# 결과 : 저체중
#
# 이름 : 가나
# 몸무게 :  66
# 키 :  176
#
# BMI : 0.002130681818181818
# 결과 : 저체중
#
# 이름 : 바가
# 몸무게 :  62
# 키 :  144
#
# BMI : 0.002989969135802469
# 결과 : 저체중
#
# 이름 : 나마
# 몸무게 :  45
# 키 :  197
#
# BMI : 0.0011595248524826716
# 결과 : 저체중
#
# 이름 : 사나
# 몸무게 :  90
# 키 :  156
#
# BMI : 0.0036982248520710057
# 결과 : 저체중
#
# 이름 : 차파
# 몸무게 :  43
# 키 :  162
#
# BMI : 0.0016384697454656302
# 결과 : 저체중
#
# 이름 : 바라
# 몸무게 :  64
# 키 :  157
#
# BMI : 0.002596454217209623
# 결과 : 저체중
#
# 이름 : 바나
# 몸무게 :  81
# 키 :  188
#
# BMI : 0.0022917609778180174
# 결과 : 저체중
#
# 이름 : 카차
# 몸무게 :  59
# 키 :  161
#
# BMI : 0.0022761467535974693
# 결과 : 저체중
#
# 이름 : 타차
# 몸무게 :  57
# 키 :  173
#
# BMI : 0.0019045073340238565
# 결과 : 저체중
#
# 이름 : 마바
# 몸무게 :  81
# 키 :  152
#
# BMI : 0.0035058864265927977
# 결과 : 저체중
#
# 이름 : 파바
# 몸무게 :  42
# 키 :  150
#
# BMI : 0.0018666666666666666
# 결과 : 저체중
#
# 이름 : 나사
# 몸무게 :  41
# 키 :  150
#
# BMI : 0.0018222222222222223
# 결과 : 저체중
#
# 이름 : 사파
# 몸무게 :  65
# 키 :  146
#
# BMI : 0.0030493525989866766
# 결과 : 저체중
#
# 이름 : 마아
# 몸무게 :  54
# 키 :  143
#
# BMI : 0.0026407159274292142
# 결과 : 저체중
#
# 이름 : 사마
# 몸무게 :  63
# 키 :  143
#
# BMI : 0.0030808352486674166
# 결과 : 저체중
#
# 이름 : 라자
# 몸무게 :  76
# 키 :  170
#
# BMI : 0.002629757785467128
# 결과 : 저체중
#
# 이름 : 타파
# 몸무게 :  66
# 키 :  171
#
# BMI : 0.0022571047501795424
# 결과 : 저체중
#
# 이름 : 라나
# 몸무게 :  55
# 키 :  152
#
# BMI : 0.002380540166204986
# 결과 : 저체중
#
# 이름 : 사타
# 몸무게 :  51
# 키 :  187
#
# BMI : 0.0014584346135148275
# 결과 : 저체중
#
# 이름 : 자바
# 몸무게 :  97
# 키 :  197
#
# BMI : 0.002499420237573759
# 결과 : 저체중
#
# 이름 : 파차
# 몸무게 :  78
# 키 :  183
#
# BMI : 0.002329122995610499
# 결과 : 저체중
#
# 이름 : 아차
# 몸무게 :  53
# 키 :  197
#
# BMI : 0.0013656626040351465
# 결과 : 저체중
#
# 이름 : 자마
# 몸무게 :  78
# 키 :  153
#
# BMI : 0.003332051774958349
# 결과 : 저체중
#
# 이름 : 아파
# 몸무게 :  51
# 키 :  158
#
# BMI : 0.0020429418362441915
# 결과 : 저체중
#
# 이름 : 마바
# 몸무게 :  84
# 키 :  141
#
# BMI : 0.004225139580503999
# 결과 : 저체중
#
# 이름 : 마차
# 몸무게 :  89
# 키 :  198
#
# BMI : 0.002270176512600755
# 결과 : 저체중
#
# 이름 : 다라
# 몸무게 :  66
# 키 :  180
#
# BMI : 0.002037037037037037
# 결과 : 저체중
#
# 이름 : 자가
# 몸무게 :  98
# 키 :  190
#
# BMI : 0.002714681440443213
# 결과 : 저체중
#
# 이름 : 카아
# 몸무게 :  51
# 키 :  144
#
# BMI : 0.002459490740740741
# 결과 : 저체중
#
# 이름 : 아가
# 몸무게 :  70
# 키 :  159
#
# BMI : 0.0027688778133776355
# 결과 : 저체중
#
# 이름 : 마라
# 몸무게 :  44
# 키 :  171
#
# BMI : 0.001504736500119695
# 결과 : 저체중
#
# 이름 : 다자
# 몸무게 :  82
# 키 :  177
#
# BMI : 0.0026173832551310288
# 결과 : 저체중
#
# 이름 : 마바
# 몸무게 :  48
# 키 :  191
#
# BMI : 0.0013157534058825142
# 결과 : 저체중
#
# 이름 : 다하
# 몸무게 :  46
# 키 :  174
#
# BMI : 0.0015193552648962874
# 결과 : 저체중
#
# 이름 : 가타
# 몸무게 :  67
# 키 :  185
#
# BMI : 0.00195763330898466
# 결과 : 저체중
#
# 이름 : 가아
# 몸무게 :  77
# 키 :  196
#
# BMI : 0.0020043731778425656
# 결과 : 저체중
#
# 이름 : 타마
# 몸무게 :  54
# 키 :  167
#
# BMI : 0.0019362472659471476
# 결과 : 저체중
#
# 이름 : 가카
# 몸무게 :  66
# 키 :  167
#
# BMI : 0.002366524436157625
# 결과 : 저체중
#
# 이름 : 나타
# 몸무게 :  80
# 키 :  172
#
# BMI : 0.0027041644131963224
# 결과 : 저체중
#
# 이름 : 차타
# 몸무게 :  49
# 키 :  170
#
# BMI : 0.0016955017301038063
# 결과 : 저체중
#
# 이름 : 라아
# 몸무게 :  80
# 키 :  149
#
# BMI : 0.003603441286428539
# 결과 : 저체중
#
# 이름 : 사바
# 몸무게 :  43
# 키 :  166
#
# BMI : 0.0015604587022789954
# 결과 : 저체중
#
# 이름 : 가하
# 몸무게 :  56
# 키 :  174
#
# BMI : 0.0018496498876998282
# 결과 : 저체중
#
# 이름 : 아사
# 몸무게 :  56
# 키 :  197
#
# BMI : 0.0014429642608673246
# 결과 : 저체중
#
# 이름 : 하가
# 몸무게 :  60
# 키 :  150
#
# BMI : 0.0026666666666666666
# 결과 : 저체중
#
# 이름 : 카카
# 몸무게 :  92
# 키 :  174
#
# BMI : 0.003038710529792575
# 결과 : 저체중
#
# 이름 : 다마
# 몸무게 :  67
# 키 :  198
#
# BMI : 0.0017090092847668605
# 결과 : 저체중
#
# 이름 : 가차
# 몸무게 :  98
# 키 :  161
#
# BMI : 0.003780718336483932
# 결과 : 저체중
#
# 이름 : 카나
# 몸무게 :  72
# 키 :  193
#
# BMI : 0.0019329377969878386
# 결과 : 저체중
#
# 이름 : 마타
# 몸무게 :  44
# 키 :  195
#
# BMI : 0.0011571334648257726
# 결과 : 저체중
#
# 이름 : 나차
# 몸무게 :  48
# 키 :  164
#
# BMI : 0.001784651992861392
# 결과 : 저체중
#
# 이름 : 타바
# 몸무게 :  59
# 키 :  167
#
# BMI : 0.002115529420201513
# 결과 : 저체중
#
# 이름 : 차라
# 몸무게 :  51
# 키 :  198
#
# BMI : 0.0013008876645240282
# 결과 : 저체중
#
# 이름 : 아바
# 몸무게 :  84
# 키 :  196
#
# BMI : 0.002186588921282799
# 결과 : 저체중
#
# 이름 : 다다
# 몸무게 :  98
# 키 :  165
#
# BMI : 0.0035996326905417815
# 결과 : 저체중
#
# 이름 : 다자
# 몸무게 :  59
# 키 :  189
#
# BMI : 0.001651689482377313
# 결과 : 저체중
#
# 이름 : 파바
# 몸무게 :  55
# 키 :  143
#
# BMI : 0.0026896180742334587
# 결과 : 저체중
#
# 이름 : 마자
# 몸무게 :  52
# 키 :  176
#
# BMI : 0.0016787190082644629
# 결과 : 저체중
#
# 이름 : 마아
# 몸무게 :  73
# 키 :  168
#
# BMI : 0.002586451247165533
# 결과 : 저체중
#
# 이름 : 가바
# 몸무게 :  91
# 키 :  159
#
# BMI : 0.003599541157390926
# 결과 : 저체중
#
# 이름 : 바나
# 몸무게 :  63
# 키 :  140
#
# BMI : 0.0032142857142857142
# 결과 : 저체중
#
# 이름 : 다차
# 몸무게 :  64
# 키 :  192
#
# BMI : 0.001736111111111111
# 결과 : 저체중
#
# 이름 : 자바
# 몸무게 :  68
# 키 :  160
#
# BMI : 0.00265625
# 결과 : 저체중
#
# 이름 : 카카
# 몸무게 :  51
# 키 :  171
#
# BMI : 0.00174412639786601
# 결과 : 저체중
#
# 이름 : 가바
# 몸무게 :  87
# 키 :  188
#
# BMI : 0.0024615210502489816
# 결과 : 저체중
#
# 이름 : 다바
# 몸무게 :  92
# 키 :  165
#
# BMI : 0.003379247015610652
# 결과 : 저체중
#
# 이름 : 타가
# 몸무게 :  59
# 키 :  180
#
# BMI : 0.0018209876543209876
# 결과 : 저체중
#
# 이름 : 다파
# 몸무게 :  86
# 키 :  149
#
# BMI : 0.0038736993829106797
# 결과 : 저체중
#
# 이름 : 자카
# 몸무게 :  86
# 키 :  171
#
# BMI : 0.0029410758865975857
# 결과 : 저체중
#
# 이름 : 마다
# 몸무게 :  50
# 키 :  190
#
# BMI : 0.0013850415512465374
# 결과 : 저체중
#
# 이름 : 카마
# 몸무게 :  56
# 키 :  155
#
# BMI : 0.0023309053069719044
# 결과 : 저체중
#
# 이름 : 다나
# 몸무게 :  45
# 키 :  156
#
# BMI : 0.0018491124260355029
# 결과 : 저체중
#
# 이름 : 마가
# 몸무게 :  71
# 키 :  141
#
# BMI : 0.0035712489311402846
# 결과 : 저체중
#
# 이름 : 사사
# 몸무게 :  93
# 키 :  140
#
# BMI : 0.004744897959183673
# 결과 : 저체중
#
# 이름 : 다라
# 몸무게 :  49
# 키 :  184
#
# BMI : 0.0014473062381852551
# 결과 : 저체중
#
# 이름 : 바마
# 몸무게 :  91
# 키 :  148
#
# BMI : 0.004154492330168006
# 결과 : 저체중
#
# 이름 : 타파
# 몸무게 :  73
# 키 :  159
#
# BMI : 0.002887544005379534
# 결과 : 저체중
#
# 이름 : 마다
# 몸무게 :  75
# 키 :  156
#
# BMI : 0.003081854043392505
# 결과 : 저체중
#
# 이름 : 가사
# 몸무게 :  90
# 키 :  180
#
# BMI : 0.002777777777777778
# 결과 : 저체중
#
# 이름 : 마라
# 몸무게 :  56
# 키 :  182
#
# BMI : 0.0016906170752324597
# 결과 : 저체중
#
# 이름 : 바하
# 몸무게 :  61
# 키 :  154
#
# BMI : 0.002572103221453871
# 결과 : 저체중
#
# 이름 : 자차
# 몸무게 :  88
# 키 :  154
#
# BMI : 0.0037105751391465678
# 결과 : 저체중
#
# 이름 : 사사
# 몸무게 :  71
# 키 :  154
#
# BMI : 0.002993759487265981
# 결과 : 저체중
#
# 이름 : 사카
# 몸무게 :  77
# 키 :  154
#
# BMI : 0.003246753246753247
# 결과 : 저체중
#
# 이름 : 자자
# 몸무게 :  62
# 키 :  143
#
# BMI : 0.0030319331018631717
# 결과 : 저체중
#
# 이름 : 타마
# 몸무게 :  67
# 키 :  158
#
# BMI : 0.0026838647652619773
# 결과 : 저체중
#
# 이름 : 타차
# 몸무게 :  79
# 키 :  184
#
# BMI : 0.002333412098298677
# 결과 : 저체중
#
# 이름 : 아나
# 몸무게 :  73
# 키 :  176
#
# BMI : 0.002356663223140496
# 결과 : 저체중
#
# 이름 : 타자
# 몸무게 :  59
# 키 :  175
#
# BMI : 0.0019265306122448979
# 결과 : 저체중
#
# 이름 : 가다
# 몸무게 :  58
# 키 :  184
#
# BMI : 0.0017131379962192818
# 결과 : 저체중
#
# 이름 : 자마
# 몸무게 :  72
# 키 :  143
#
# BMI : 0.003520954569905619
# 결과 : 저체중
#
# 이름 : 라차
# 몸무게 :  72
# 키 :  166
#
# BMI : 0.00261286108288576
# 결과 : 저체중
#
# 이름 : 아차
# 몸무게 :  76
# 키 :  187
#
# BMI : 0.0021733535417083703
# 결과 : 저체중
#
# 이름 : 차아
# 몸무게 :  94
# 키 :  159
#
# BMI : 0.003718207349392825
# 결과 : 저체중
#
# 이름 : 파파
# 몸무게 :  84
# 키 :  199
#
# BMI : 0.002121158556602106
# 결과 : 저체중
#
# 이름 : 다차
# 몸무게 :  85
# 키 :  151
#
# BMI : 0.0037279066707600543
# 결과 : 저체중
#
# 이름 : 바타
# 몸무게 :  94
# 키 :  147
#
# BMI : 0.004350039335462076
# 결과 : 저체중
#
# 이름 : 파하
# 몸무게 :  59
# 키 :  197
#
# BMI : 0.0015202659176995028
# 결과 : 저체중
#
# 이름 : 차자
# 몸무게 :  66
# 키 :  180
#
# BMI : 0.002037037037037037
# 결과 : 저체중
#
# 이름 : 하마
# 몸무게 :  68
# 키 :  197
#
# BMI : 0.001752170888196037
# 결과 : 저체중
#
# 이름 : 바바
# 몸무게 :  43
# 키 :  140
#
# BMI : 0.002193877551020408
# 결과 : 저체중
#
# 이름 : 다다
# 몸무게 :  87
# 키 :  185
#
# BMI : 0.00254200146092038
# 결과 : 저체중
#
# 이름 : 다다
# 몸무게 :  77
# 키 :  195
#
# BMI : 0.002024983563445102
# 결과 : 저체중
#
# 이름 : 라자
# 몸무게 :  91
# 키 :  153
#
# BMI : 0.0038873937374514075
# 결과 : 저체중
#
# 이름 : 가가
# 몸무게 :  62
# 키 :  175
#
# BMI : 0.002024489795918367
# 결과 : 저체중
#
# 이름 : 자가
# 몸무게 :  90
# 키 :  160
#
# BMI : 0.003515625
# 결과 : 저체중
#
# 이름 : 자타
# 몸무게 :  78
# 키 :  157
#
# BMI : 0.003164428577224228
# 결과 : 저체중
#
# 이름 : 사나
# 몸무게 :  48
# 키 :  199
#
# BMI : 0.001212090603772632
# 결과 : 저체중
#
# 이름 : 타가
# 몸무게 :  56
# 키 :  191
#
# BMI : 0.0015350456401962665
# 결과 : 저체중
#
# 이름 : 사사
# 몸무게 :  67
# 키 :  186
#
# BMI : 0.001936640073996994
# 결과 : 저체중
#
# 이름 : 파차
# 몸무게 :  80
# 키 :  197
#
# BMI : 0.0020613775155247493
# 결과 : 저체중
#
# 이름 : 아바
# 몸무게 :  60
# 키 :  174
#
# BMI : 0.0019817677368212444
# 결과 : 저체중
#
# 이름 : 라자
# 몸무게 :  43
# 키 :  191
#
# BMI : 0.001178695759436419
# 결과 : 저체중
#
# 이름 : 아나
# 몸무게 :  98
# 키 :  176
#
# BMI : 0.0031637396694214875
# 결과 : 저체중
#
# 이름 : 하다
# 몸무게 :  78
# 키 :  143
#
# BMI : 0.003814367450731087
# 결과 : 저체중
#
# 이름 : 가마
# 몸무게 :  87
# 키 :  152
#
# BMI : 0.0037655817174515236
# 결과 : 저체중
#
# 이름 : 하아
# 몸무게 :  89
# 키 :  161
#
# BMI : 0.003433509509663979
# 결과 : 저체중
#
# 이름 : 다마
# 몸무게 :  88
# 키 :  178
#
# BMI : 0.002777427092538821
# 결과 : 저체중
#
# 이름 : 자다
# 몸무게 :  72
# 키 :  185
#
# BMI : 0.00210372534696859
# 결과 : 저체중
#
# 이름 : 차마
# 몸무게 :  74
# 키 :  185
#
# BMI : 0.002162162162162162
# 결과 : 저체중
#
# 이름 : 차하
# 몸무게 :  52
# 키 :  160
#
# BMI : 0.00203125
# 결과 : 저체중
#
# 이름 : 바아
# 몸무게 :  73
# 키 :  187
#
# BMI : 0.0020875632703251453
# 결과 : 저체중
#
# 이름 : 하하
# 몸무게 :  53
# 키 :  174
#
# BMI : 0.001750561500858766
# 결과 : 저체중
#
# 이름 : 나자
# 몸무게 :  49
# 키 :  154
#
# BMI : 0.002066115702479339
# 결과 : 저체중
#
# 이름 : 자타
# 몸무게 :  46
# 키 :  193
#
# BMI : 0.001234932481408897
# 결과 : 저체중
#
# 이름 : 라차
# 몸무게 :  48
# 키 :  188
#
# BMI : 0.001358080579447714
# 결과 : 저체중
#
# 이름 : 파하
# 몸무게 :  42
# 키 :  148
#
# BMI : 0.0019174579985390796
# 결과 : 저체중
#
# 이름 : 다사
# 몸무게 :  52
# 키 :  141
#
# BMI : 0.0026155625974548565
# 결과 : 저체중
#
# 이름 : 가가
# 몸무게 :  76
# 키 :  148
#
# BMI : 0.0034696859021183346
# 결과 : 저체중
#
# 이름 : 가자
# 몸무게 :  75
# 키 :  167
#
# BMI : 0.002689232313815483
# 결과 : 저체중
#
# 이름 : 카자
# 몸무게 :  79
# 키 :  198
#
# BMI : 0.0020151004999489847
# 결과 : 저체중
#
# 이름 : 파나
# 몸무게 :  86
# 키 :  197
#
# BMI : 0.0022159808291891056
# 결과 : 저체중
#
# 이름 : 가카
# 몸무게 :  88
# 키 :  172
#
# BMI : 0.0029745808545159546
# 결과 : 저체중
#
# 이름 : 가마
# 몸무게 :  75
# 키 :  195
#
# BMI : 0.0019723865877712033
# 결과 : 저체중
#
# 이름 : 자라
# 몸무게 :  58
# 키 :  163
#
# BMI : 0.002182995219993225
# 결과 : 저체중
#
# 이름 : 파카
# 몸무게 :  52
# 키 :  153
#
# BMI : 0.002221367849972233
# 결과 : 저체중
#
# 이름 : 파파
# 몸무게 :  45
# 키 :  155
#
# BMI : 0.0018730489073881373
# 결과 : 저체중
#
# 이름 : 바아
# 몸무게 :  92
# 키 :  166
#
# BMI : 0.0033386558281318043
# 결과 : 저체중
#
# 이름 : 마파
# 몸무게 :  42
# 키 :  164
#
# BMI : 0.001561570493753718
# 결과 : 저체중
#
# 이름 : 카다
# 몸무게 :  47
# 키 :  145
#
# BMI : 0.002235434007134364
# 결과 : 저체중
#
# 이름 : 바나
# 몸무게 :  80
# 키 :  150
#
# BMI : 0.0035555555555555557
# 결과 : 저체중
#
# 이름 : 자하
# 몸무게 :  99
# 키 :  147
#
# BMI : 0.004581424406497293
# 결과 : 저체중
#
# 이름 : 가자
# 몸무게 :  62
# 키 :  146
#
# BMI : 0.0029086132482642147
# 결과 : 저체중
#
# 이름 : 라파
# 몸무게 :  62
# 키 :  190
#
# BMI : 0.0017174515235457064
# 결과 : 저체중
#
# 이름 : 자다
# 몸무게 :  84
# 키 :  181
#
# BMI : 0.0025640242971826255
# 결과 : 저체중
#
# 이름 : 아마
# 몸무게 :  70
# 키 :  147
#
# BMI : 0.003239390994493035
# 결과 : 저체중
#
# 이름 : 차아
# 몸무게 :  93
# 키 :  161
#
# BMI : 0.0035878245438061805
# 결과 : 저체중
#
# 이름 : 차카
# 몸무게 :  55
# 키 :  162
#
# BMI : 0.002095717116293248
# 결과 : 저체중
#
# 이름 : 마파
# 몸무게 :  68
# 키 :  170
#
# BMI : 0.002352941176470588
# 결과 : 저체중
#
# 이름 : 아사
# 몸무게 :  44
# 키 :  173
#
# BMI : 0.001470146012228942
# 결과 : 저체중
#
# 이름 : 카가
# 몸무게 :  53
# 키 :  176
#
# BMI : 0.0017110020661157024
# 결과 : 저체중
#
# 이름 : 타하
# 몸무게 :  67
# 키 :  188
#
# BMI : 0.0018956541421457673
# 결과 : 저체중
#
# 이름 : 차마
# 몸무게 :  91
# 키 :  177
#
# BMI : 0.002904657027035654
# 결과 : 저체중
#
# 이름 : 사마
# 몸무게 :  67
# 키 :  168
#
# BMI : 0.0023738662131519276
# 결과 : 저체중
#
# 이름 : 차파
# 몸무게 :  75
# 키 :  195
#
# BMI : 0.0019723865877712033
# 결과 : 저체중
#
# 이름 : 타마
# 몸무게 :  92
# 키 :  141
#
# BMI : 0.004627533826266284
# 결과 : 저체중
#
# 이름 : 자가
# 몸무게 :  85
# 키 :  160
#
# BMI : 0.0033203125
# 결과 : 저체중
#
# 이름 : 바다
# 몸무게 :  77
# 키 :  186
#
# BMI : 0.002225690831309978
# 결과 : 저체중
#
# 이름 : 아차
# 몸무게 :  79
# 키 :  180
#
# BMI : 0.0024382716049382715
# 결과 : 저체중
#
# 이름 : 다아
# 몸무게 :  94
# 키 :  173
#
# BMI : 0.003140766480670921
# 결과 : 저체중
#
# 이름 : 사가
# 몸무게 :  66
# 키 :  166
#
# BMI : 0.0023951226593119466
# 결과 : 저체중
#
# 이름 : 아다
# 몸무게 :  82
# 키 :  192
#
# BMI : 0.002224392361111111
# 결과 : 저체중
#
# 이름 : 바마
# 몸무게 :  77
# 키 :  195
#
# BMI : 0.002024983563445102
# 결과 : 저체중
#
# 이름 : 바차
# 몸무게 :  95
# 키 :  159
#
# BMI : 0.003757762746726791
# 결과 : 저체중
#
# 이름 : 바라
# 몸무게 :  87
# 키 :  151
#
# BMI : 0.0038156221218367615
# 결과 : 저체중
#
# 이름 : 차파
# 몸무게 :  41
# 키 :  173
#
# BMI : 0.001369908784122423
# 결과 : 저체중
#
# 이름 : 자카
# 몸무게 :  59
# 키 :  195
#
# BMI : 0.0015516107823800131
# 결과 : 저체중
#
# 이름 : 하사
# 몸무게 :  75
# 키 :  184
#
# BMI : 0.0022152646502835538
# 결과 : 저체중
#
# 이름 : 사하
# 몸무게 :  96
# 키 :  195
#
# BMI : 0.00252465483234714
# 결과 : 저체중
#
# 이름 : 다파
# 몸무게 :  74
# 키 :  180
#
# BMI : 0.002283950617283951
# 결과 : 저체중
#
# 이름 : 하사
# 몸무게 :  52
# 키 :  192
#
# BMI : 0.0014105902777777778
# 결과 : 저체중
#
# 이름 : 마나
# 몸무게 :  53
# 키 :  197
#
# BMI : 0.0013656626040351465
# 결과 : 저체중
#
# 이름 : 자가
# 몸무게 :  69
# 키 :  143
#
# BMI : 0.0033742481294928846
# 결과 : 저체중
#
# 이름 : 사카
# 몸무게 :  66
# 키 :  168
#
# BMI : 0.00233843537414966
# 결과 : 저체중
#
# 이름 : 사카
# 몸무게 :  43
# 키 :  172
#
# BMI : 0.0014534883720930232
# 결과 : 저체중
#
# 이름 : 카사
# 몸무게 :  79
# 키 :  149
#
# BMI : 0.0035583982703481826
# 결과 : 저체중
#
# 이름 : 다하
# 몸무게 :  93
# 키 :  160
#
# BMI : 0.0036328125
# 결과 : 저체중
#
# 이름 : 라카
# 몸무게 :  57
# 키 :  189
#
# BMI : 0.001595700008398421
# 결과 : 저체중
#
# 이름 : 나차
# 몸무게 :  46
# 키 :  190
#
# BMI : 0.0012742382271468144
# 결과 : 저체중
#
# 이름 : 마자
# 몸무게 :  71
# 키 :  164
#
# BMI : 0.002639797739440809
# 결과 : 저체중
#
# 이름 : 자자
# 몸무게 :  48
# 키 :  183
#
# BMI : 0.0014333064588372302
# 결과 : 저체중
#
# 이름 : 파가
# 몸무게 :  94
# 키 :  147
#
# BMI : 0.004350039335462076
# 결과 : 저체중
#
# 이름 : 파타
# 몸무게 :  62
# 키 :  191
#
# BMI : 0.0016995148159315808
# 결과 : 저체중
#
# 이름 : 타마
# 몸무게 :  83
# 키 :  198
#
# BMI : 0.0021171309050096927
# 결과 : 저체중
#
# 이름 : 카다
# 몸무게 :  43
# 키 :  195
#
# BMI : 0.0011308349769888232
# 결과 : 저체중
#
# 이름 : 자하
# 몸무게 :  77
# 키 :  171
#
# BMI : 0.0026332888752094662
# 결과 : 저체중
#
# 이름 : 나가
# 몸무게 :  64
# 키 :  195
#
# BMI : 0.00168310322156476
# 결과 : 저체중
#
# 이름 : 나가
# 몸무게 :  41
# 키 :  148
#
# BMI : 0.0018718042366691015
# 결과 : 저체중
#
# 이름 : 카카
# 몸무게 :  95
# 키 :  174
#
# BMI : 0.0031377989166336373
# 결과 : 저체중
#
# 이름 : 차나
# 몸무게 :  57
# 키 :  174
#
# BMI : 0.0018826793499801824
# 결과 : 저체중
#
# 이름 : 라차
# 몸무게 :  85
# 키 :  149
#
# BMI : 0.003828656366830323
# 결과 : 저체중
#
# 이름 : 나카
# 몸무게 :  76
# 키 :  166
#
# BMI : 0.002758020031934969
# 결과 : 저체중
#
# 이름 : 마하
# 몸무게 :  77
# 키 :  181
#
# BMI : 0.00235035560575074
# 결과 : 저체중
#
# 이름 : 카마
# 몸무게 :  48
# 키 :  167
#
# BMI : 0.001721108680841909
# 결과 : 저체중
#
# 이름 : 자마
# 몸무게 :  74
# 키 :  161
#
# BMI : 0.002854828131630724
# 결과 : 저체중
#
# 이름 : 바가
# 몸무게 :  56
# 키 :  190
#
# BMI : 0.0015512465373961218
# 결과 : 저체중
#
# 이름 : 사가
# 몸무게 :  92
# 키 :  187
#
# BMI : 0.002630901655752238
# 결과 : 저체중
#
# 이름 : 차파
# 몸무게 :  82
# 키 :  166
#
# BMI : 0.002975758455508782
# 결과 : 저체중
#
# 이름 : 자마
# 몸무게 :  46
# 키 :  174
#
# BMI : 0.0015193552648962874
# 결과 : 저체중
#
# 이름 : 아아
# 몸무게 :  95
# 키 :  174
#
# BMI : 0.0031377989166336373
# 결과 : 저체중
#
# 이름 : 사나
# 몸무게 :  57
# 키 :  162
#
# BMI : 0.0021719250114311845
# 결과 : 저체중
#
# 이름 : 라차
# 몸무게 :  91
# 키 :  174
#
# BMI : 0.0030056810675122207
# 결과 : 저체중
#
# 이름 : 아나
# 몸무게 :  91
# 키 :  155
#
# BMI : 0.0037877211238293443
# 결과 : 저체중
#
# 이름 : 아타
# 몸무게 :  69
# 키 :  197
#
# BMI : 0.0017779381071400964
# 결과 : 저체중
#
# 이름 : 사사
# 몸무게 :  65
# 키 :  199
#
# BMI : 0.0016413726926087725
# 결과 : 저체중
#
# 이름 : 가하
# 몸무게 :  70
# 키 :  187
#
# BMI : 0.00200177299894192
# 결과 : 저체중
#
# 이름 : 아카
# 몸무게 :  54
# 키 :  183
#
# BMI : 0.0016124697661918839
# 결과 : 저체중
#
# 이름 : 다파
# 몸무게 :  90
# 키 :  176
#
# BMI : 0.00290547520661157
# 결과 : 저체중
#
# 이름 : 나바
# 몸무게 :  81
# 키 :  160
#
# BMI : 0.0031640625
# 결과 : 저체중
#
# 이름 : 라가
# 몸무게 :  64
# 키 :  196
#
# BMI : 0.001665972511453561
# 결과 : 저체중
#
# 이름 : 사차
# 몸무게 :  47
# 키 :  164
#
# BMI : 0.001747471743010113
# 결과 : 저체중
#
# 이름 : 차아
# 몸무게 :  92
# 키 :  156
#
# BMI : 0.003780407626561473
# 결과 : 저체중
#
# 이름 : 다차
# 몸무게 :  42
# 키 :  170
#
# BMI : 0.0014532871972318339
# 결과 : 저체중
#
# 이름 : 다라
# 몸무게 :  88
# 키 :  190
#
# BMI : 0.002437673130193906
# 결과 : 저체중
#
# 이름 : 나가
# 몸무게 :  48
# 키 :  191
#
# BMI : 0.0013157534058825142
# 결과 : 저체중
#
# 이름 : 바자
# 몸무게 :  45
# 키 :  140
#
# BMI : 0.002295918367346939
# 결과 : 저체중
#
# 이름 : 타차
# 몸무게 :  80
# 키 :  169
#
# BMI : 0.0028010223731662056
# 결과 : 저체중
#
# 이름 : 사아
# 몸무게 :  64
# 키 :  150
#
# BMI : 0.0028444444444444446
# 결과 : 저체중
#
# 이름 : 나다
# 몸무게 :  80
# 키 :  196
#
# BMI : 0.0020824656393169513
# 결과 : 저체중
#
# 이름 : 차하
# 몸무게 :  85
# 키 :  161
#
# BMI : 0.003279194475521778
# 결과 : 저체중
#
# 이름 : 가마
# 몸무게 :  58
# 키 :  177
#
# BMI : 0.0018513198633853618
# 결과 : 저체중
#
# 이름 : 사바
# 몸무게 :  50
# 키 :  163
#
# BMI : 0.0018818924310286425
# 결과 : 저체중
#
# 이름 : 자카
# 몸무게 :  57
# 키 :  172
#
# BMI : 0.0019267171444023797
# 결과 : 저체중
#
# 이름 : 마라
# 몸무게 :  48
# 키 :  181
#
# BMI : 0.0014651567412472147
# 결과 : 저체중
#
# 이름 : 아바
# 몸무게 :  71
# 키 :  140
#
# BMI : 0.003622448979591837
# 결과 : 저체중
#
# 이름 : 아사
# 몸무게 :  49
# 키 :  152
#
# BMI : 0.0021208448753462605
# 결과 : 저체중
#
# 이름 : 카나
# 몸무게 :  47
# 키 :  143
#
# BMI : 0.0022984008997995013
# 결과 : 저체중
#
# 이름 : 아바
# 몸무게 :  79
# 키 :  179
#
# BMI : 0.002465590961580475
# 결과 : 저체중
#
# 이름 : 마아
# 몸무게 :  91
# 키 :  179
#
# BMI : 0.002840111107643332
# 결과 : 저체중
#
# 이름 : 자마
# 몸무게 :  92
# 키 :  160
#
# BMI : 0.00359375
# 결과 : 저체중
#
# 이름 : 마아
# 몸무게 :  62
# 키 :  179
#
# BMI : 0.0019350207546580942
# 결과 : 저체중
#
# 이름 : 파라
# 몸무게 :  40
# 키 :  198
#
# BMI : 0.001020304050607081
# 결과 : 저체중
#
# 이름 : 아하
# 몸무게 :  71
# 키 :  197
#
# BMI : 0.001829472545028215
# 결과 : 저체중
#
# 이름 : 바카
# 몸무게 :  81
# 키 :  159
#
# BMI : 0.003203987184051264
# 결과 : 저체중
#
# 이름 : 바사
# 몸무게 :  55
# 키 :  169
#
# BMI : 0.0019257028815517663
# 결과 : 저체중
#
# 이름 : 하나
# 몸무게 :  94
# 키 :  141
#
# BMI : 0.004728132387706856
# 결과 : 저체중
#
# 이름 : 카아
# 몸무게 :  60
# 키 :  196
#
# BMI : 0.0015618492294877135
# 결과 : 저체중
#
# 이름 : 사타
# 몸무게 :  68
# 키 :  156
#
# BMI : 0.002794214332675871
# 결과 : 저체중
#
# 이름 : 자아
# 몸무게 :  77
# 키 :  160
#
# BMI : 0.0030078125
# 결과 : 저체중
#
# 이름 : 라라
# 몸무게 :  48
# 키 :  171
#
# BMI : 0.0016415307274033036
# 결과 : 저체중
#
# 이름 : 라마
# 몸무게 :  59
# 키 :  195
#
# BMI : 0.0015516107823800131
# 결과 : 저체중
#
# 이름 : 자아
# 몸무게 :  93
# 키 :  147
#
# BMI : 0.004303762321255033
# 결과 : 저체중
#
# 이름 : 파다
# 몸무게 :  46
# 키 :  194
#
# BMI : 0.0012222340312466786
# 결과 : 저체중
#
# 이름 : 사라
# 몸무게 :  58
# 키 :  186
#
# BMI : 0.001676494392415308
# 결과 : 저체중
#
# 이름 : 카가
# 몸무게 :  86
# 키 :  142
#
# BMI : 0.004265026780400714
# 결과 : 저체중
#
# 이름 : 하라
# 몸무게 :  85
# 키 :  155
#
# BMI : 0.003537981269510926
# 결과 : 저체중
#
# 이름 : 사카
# 몸무게 :  81
# 키 :  195
#
# BMI : 0.0021301775147928993
# 결과 : 저체중
#
# 이름 : 차카
# 몸무게 :  68
# 키 :  198
#
# BMI : 0.0017345168860320376
# 결과 : 저체중
#
# 이름 : 자다
# 몸무게 :  82
# 키 :  189
#
# BMI : 0.0022955684331345707
# 결과 : 저체중
#
# 이름 : 타가
# 몸무게 :  60
# 키 :  195
#
# BMI : 0.0015779092702169625
# 결과 : 저체중
#
# 이름 : 파타
# 몸무게 :  49
# 키 :  156
#
# BMI : 0.0020134779750164366
# 결과 : 저체중
#
# 이름 : 하가
# 몸무게 :  45
# 키 :  195
#
# BMI : 0.001183431952662722
# 결과 : 저체중
#
# 이름 : 라파
# 몸무게 :  92
# 키 :  158
#
# BMI : 0.0036853068418522673
# 결과 : 저체중
#
# 이름 : 바파
# 몸무게 :  45
# 키 :  192
#
# BMI : 0.001220703125
# 결과 : 저체중
#
# 이름 : 다타
# 몸무게 :  43
# 키 :  167
#
# BMI : 0.0015418265265875436
# 결과 : 저체중
#
# 이름 : 라아
# 몸무게 :  43
# 키 :  173
#
# BMI : 0.0014367336028601023
# 결과 : 저체중
#
# 이름 : 자자
# 몸무게 :  45
# 키 :  186
#
# BMI : 0.0013007284079084287
# 결과 : 저체중
#
# 이름 : 하가
# 몸무게 :  70
# 키 :  148
#
# BMI : 0.003195763330898466
# 결과 : 저체중
#
# 이름 : 사가
# 몸무게 :  76
# 키 :  183
#
# BMI : 0.0022694018931589477
# 결과 : 저체중
#
# 이름 : 마자
# 몸무게 :  65
# 키 :  175
#
# BMI : 0.0021224489795918368
# 결과 : 저체중
#
# 이름 : 다하
# 몸무게 :  47
# 키 :  199
#
# BMI : 0.0011868387161940355
# 결과 : 저체중
#
# 이름 : 타파
# 몸무게 :  78
# 키 :  172
#
# BMI : 0.0026365603028664143
# 결과 : 저체중
#
# 이름 : 다타
# 몸무게 :  71
# 키 :  156
#
# BMI : 0.0029174884944115713
# 결과 : 저체중
#
# 이름 : 나다
# 몸무게 :  54
# 키 :  187
#
# BMI : 0.0015442248848980525
# 결과 : 저체중
#
# 이름 : 타나
# 몸무게 :  76
# 키 :  189
#
# BMI : 0.002127600011197895
# 결과 : 저체중
#
# 이름 : 사사
# 몸무게 :  70
# 키 :  177
#
# BMI : 0.002234351559258195
# 결과 : 저체중
#
# 이름 : 자파
# 몸무게 :  79
# 키 :  189
#
# BMI : 0.002211584222166233
# 결과 : 저체중
#
# 이름 : 카아
# 몸무게 :  45
# 키 :  171
#
# BMI : 0.0015389350569405972
# 결과 : 저체중
#
# 이름 : 자타
# 몸무게 :  43
# 키 :  181
#
# BMI : 0.0013125362473672966
# 결과 : 저체중
#
# 이름 : 타타
# 몸무게 :  92
# 키 :  199
#
# BMI : 0.0023231736572308782
# 결과 : 저체중
#
# 이름 : 타바
# 몸무게 :  86
# 키 :  150
#
# BMI : 0.003822222222222222
# 결과 : 저체중
#
# 이름 : 타가
# 몸무게 :  91
# 키 :  195
#
# BMI : 0.002393162393162393
# 결과 : 저체중
#
# 이름 : 차타
# 몸무게 :  48
# 키 :  140
#
# BMI : 0.0024489795918367346
# 결과 : 저체중
#
# 이름 : 카타
# 몸무게 :  45
# 키 :  179
#
# BMI : 0.0014044505477357136
# 결과 : 저체중
#
# 이름 : 나마
# 몸무게 :  97
# 키 :  189
#
# BMI : 0.0027154894879762603
# 결과 : 저체중
#
# 이름 : 사다
# 몸무게 :  82
# 키 :  164
#
# BMI : 0.003048780487804878
# 결과 : 저체중
#
# 이름 : 사사
# 몸무게 :  44
# 키 :  151
#
# BMI : 0.0019297399236875576
# 결과 : 저체중
#
# 이름 : 다카
# 몸무게 :  84
# 키 :  187
#
# BMI : 0.002402127598730304
# 결과 : 저체중
#
# 이름 : 차나
# 몸무게 :  96
# 키 :  151
#
# BMI : 0.004210341651681944
# 결과 : 저체중
#
# 이름 : 가하
# 몸무게 :  78
# 키 :  159
#
# BMI : 0.0030853209920493653
# 결과 : 저체중
#
# 이름 : 자사
# 몸무게 :  81
# 키 :  142
#
# BMI : 0.004017060107121603
# 결과 : 저체중
#
# 이름 : 카타
# 몸무게 :  67
# 키 :  190
#
# BMI : 0.0018559556786703602
# 결과 : 저체중
#
# 이름 : 자다
# 몸무게 :  76
# 키 :  153
#
# BMI : 0.0032466145499594175
# 결과 : 저체중
#
# 이름 : 카하
# 몸무게 :  47
# 키 :  172
#
# BMI : 0.0015886965927528393
# 결과 : 저체중
#
# 이름 : 자다
# 몸무게 :  81
# 키 :  170
#
# BMI : 0.0028027681660899653
# 결과 : 저체중
#
# 이름 : 카하
# 몸무게 :  94
# 키 :  165
#
# BMI : 0.003452708907254362
# 결과 : 저체중
#
# 이름 : 바가
# 몸무게 :  65
# 키 :  165
#
# BMI : 0.0023875114784205694
# 결과 : 저체중
#
# 이름 : 마라
# 몸무게 :  92
# 키 :  188
#
# BMI : 0.002602987777274785
# 결과 : 저체중
#
# 이름 : 가카
# 몸무게 :  70
# 키 :  171
#
# BMI : 0.002393898977463151
# 결과 : 저체중
#
# 이름 : 나마
# 몸무게 :  47
# 키 :  167
#
# BMI : 0.0016852522499910358
# 결과 : 저체중
#
# 이름 : 카차
# 몸무게 :  96
# 키 :  157
#
# BMI : 0.0038946813258144346
# 결과 : 저체중
#
# 이름 : 마라
# 몸무게 :  64
# 키 :  150
#
# BMI : 0.0028444444444444446
# 결과 : 저체중
#
# 이름 : 라파
# 몸무게 :  83
# 키 :  149
#
# BMI : 0.0037385703346696094
# 결과 : 저체중
#
# 이름 : 나가
# 몸무게 :  50
# 키 :  177
#
# BMI : 0.0015959653994701394
# 결과 : 저체중
#
# 이름 : 카차
# 몸무게 :  96
# 키 :  189
#
# BMI : 0.0026874947509868143
# 결과 : 저체중
#
# 이름 : 아자
# 몸무게 :  58
# 키 :  161
#
# BMI : 0.002237567995061919
# 결과 : 저체중
#
# 이름 : 타사
# 몸무게 :  88
# 키 :  150
#
# BMI : 0.003911111111111111
# 결과 : 저체중
#
# 이름 : 다하
# 몸무게 :  79
# 키 :  163
#
# BMI : 0.002973390041025255
# 결과 : 저체중
#
# 이름 : 카차
# 몸무게 :  82
# 키 :  199
#
# BMI : 0.002070654781444913
# 결과 : 저체중
#
# 이름 : 라카
# 몸무게 :  66
# 키 :  176
#
# BMI : 0.002130681818181818
# 결과 : 저체중
#
# 이름 : 자자
# 몸무게 :  58
# 키 :  191
#
# BMI : 0.0015898686987747047
# 결과 : 저체중
#
# 이름 : 아아
# 몸무게 :  98
# 키 :  160
#
# BMI : 0.003828125
# 결과 : 저체중
#
# 이름 : 카하
# 몸무게 :  76
# 키 :  198
#
# BMI : 0.0019385776961534538
# 결과 : 저체중
#
# 이름 : 라하
# 몸무게 :  78
# 키 :  155
#
# BMI : 0.003246618106139438
# 결과 : 저체중
#
# 이름 : 자마
# 몸무게 :  61
# 키 :  170
#
# BMI : 0.002110726643598616
# 결과 : 저체중
#
# 이름 : 차가
# 몸무게 :  62
# 키 :  151
#
# BMI : 0.002719178983377922
# 결과 : 저체중
#
# 이름 : 카아
# 몸무게 :  41
# 키 :  152
#
# BMI : 0.001774584487534626
# 결과 : 저체중
#
# 이름 : 다바
# 몸무게 :  90
# 키 :  156
#
# BMI : 0.0036982248520710057
# 결과 : 저체중
#
# 이름 : 마차
# 몸무게 :  97
# 키 :  153
#
# BMI : 0.004143705412448203
# 결과 : 저체중
#
# 이름 : 차파
# 몸무게 :  74
# 키 :  175
#
# BMI : 0.002416326530612245
# 결과 : 저체중
#
# 이름 : 파아
# 몸무게 :  90
# 키 :  199
#
# BMI : 0.002272669882073685
# 결과 : 저체중
#
# 이름 : 라가
# 몸무게 :  78
# 키 :  147
#
# BMI : 0.003609607108149382
# 결과 : 저체중
#
# 이름 : 파카
# 몸무게 :  52
# 키 :  160
#
# BMI : 0.00203125
# 결과 : 저체중
#
# 이름 : 아라
# 몸무게 :  89
# 키 :  141
#
# BMI : 0.004476635984105427
# 결과 : 저체중
#
# 이름 : 아다
# 몸무게 :  79
# 키 :  140
#
# BMI : 0.004030612244897959
# 결과 : 저체중
#
# 이름 : 가마
# 몸무게 :  78
# 키 :  192
#
# BMI : 0.0021158854166666665
# 결과 : 저체중
#
# 이름 : 타마
# 몸무게 :  92
# 키 :  140
#
# BMI : 0.004693877551020408
# 결과 : 저체중
#
# 이름 : 마나
# 몸무게 :  71
# 키 :  164
#
# BMI : 0.002639797739440809
# 결과 : 저체중
#
# 이름 : 카아
# 몸무게 :  88
# 키 :  181
#
# BMI : 0.0026861206922865603
# 결과 : 저체중
#
# 이름 : 마하
# 몸무게 :  87
# 키 :  192
#
# BMI : 0.0023600260416666665
# 결과 : 저체중
#
# 이름 : 하타
# 몸무게 :  49
# 키 :  183
#
# BMI : 0.0014631670100630058
# 결과 : 저체중
#
# 이름 : 다사
# 몸무게 :  48
# 키 :  151
#
# BMI : 0.002105170825840972
# 결과 : 저체중
#
# 이름 : 가다
# 몸무게 :  88
# 키 :  196
#
# BMI : 0.0022907122032486465
# 결과 : 저체중
#
# 이름 : 나마
# 몸무게 :  57
# 키 :  147
#
# BMI : 0.0026377898098014717
# 결과 : 저체중
#
# 이름 : 차카
# 몸무게 :  50
# 키 :  186
#
# BMI : 0.0014452537865649207
# 결과 : 저체중
#
# 이름 : 라파
# 몸무게 :  83
# 키 :  165
#
# BMI : 0.003048668503213958
# 결과 : 저체중
#
# 이름 : 타하
# 몸무게 :  66
# 키 :  188
#
# BMI : 0.0018673607967406066
# 결과 : 저체중
#
# 이름 : 나사
# 몸무게 :  83
# 키 :  185
#
# BMI : 0.002425127830533236
# 결과 : 저체중
#
# 이름 : 자나
# 몸무게 :  51
# 키 :  185
#
# BMI : 0.0014901387874360847
# 결과 : 저체중
#
# 이름 : 파나
# 몸무게 :  73
# 키 :  197
#
# BMI : 0.0018810069829163338
# 결과 : 저체중
#
# 이름 : 카마
# 몸무게 :  44
# 키 :  142
#
# BMI : 0.0021821067248561795
# 결과 : 저체중
#
# 이름 : 사다
# 몸무게 :  69
# 키 :  191
#
# BMI : 0.0018913955209561141
# 결과 : 저체중
#
# 이름 : 사사
# 몸무게 :  55
# 키 :  167
#
# BMI : 0.0019721036967980205
# 결과 : 저체중
#
# 이름 : 다카
# 몸무게 :  42
# 키 :  189
#
# BMI : 0.0011757789535567313
# 결과 : 저체중
#
# 이름 : 가다
# 몸무게 :  74
# 키 :  177
#
# BMI : 0.0023620287912158064
# 결과 : 저체중
#
# 이름 : 하자
# 몸무게 :  78
# 키 :  188
#
# BMI : 0.002206880941602535
# 결과 : 저체중
#
# 이름 : 자아
# 몸무게 :  64
# 키 :  192
#
# BMI : 0.001736111111111111
# 결과 : 저체중
#
# 이름 : 가바
# 몸무게 :  99
# 키 :  141
#
# BMI : 0.004979628791308284
# 결과 : 저체중
#
# 이름 : 마라
# 몸무게 :  72
# 키 :  199
#
# BMI : 0.001818135905658948
# 결과 : 저체중
#
# 이름 : 사사
# 몸무게 :  75
# 키 :  151
#
# BMI : 0.0032893294153765185
# 결과 : 저체중
#
# 이름 : 파나
# 몸무게 :  83
# 키 :  187
#
# BMI : 0.0023735308416025624
# 결과 : 저체중
#
# 이름 : 파타
# 몸무게 :  53
# 키 :  141
#
# BMI : 0.0026658618781751423
# 결과 : 저체중
#
# 이름 : 타카
# 몸무게 :  67
# 키 :  199
#
# BMI : 0.0016918764677659654
# 결과 : 저체중
#
# 이름 : 파하
# 몸무게 :  44
# 키 :  151
#
# BMI : 0.0019297399236875576
# 결과 : 저체중
#
# 이름 : 사자
# 몸무게 :  79
# 키 :  198
#
# BMI : 0.0020151004999489847
# 결과 : 저체중
#
# 이름 : 나다
# 몸무게 :  49
# 키 :  181
#
# BMI : 0.0014956808400231982
# 결과 : 저체중
#
# 이름 : 가다
# 몸무게 :  64
# 키 :  197
#
# BMI : 0.0016491020124197995
# 결과 : 저체중
#
# 이름 : 가타
# 몸무게 :  73
# 키 :  164
#
# BMI : 0.002714158239143367
# 결과 : 저체중
#
# 이름 : 아카
# 몸무게 :  67
# 키 :  192
#
# BMI : 0.0018174913194444445
# 결과 : 저체중
#
# 이름 : 하마
# 몸무게 :  48
# 키 :  194
#
# BMI : 0.001275374641300882
# 결과 : 저체중
#
# 이름 : 나타
# 몸무게 :  98
# 키 :  176
#
# BMI : 0.0031637396694214875
# 결과 : 저체중
#
# 이름 : 사다
# 몸무게 :  67
# 키 :  144
#
# BMI : 0.0032310956790123457
# 결과 : 저체중
#
# 이름 : 바바
# 몸무게 :  66
# 키 :  155
#
# BMI : 0.0027471383975026012
# 결과 : 저체중
#
# 이름 : 사마
# 몸무게 :  75
# 키 :  164
#
# BMI : 0.0027885187388459252
# 결과 : 저체중
#
# 이름 : 타하
# 몸무게 :  44
# 키 :  197
#
# BMI : 0.0011337576335386122
# 결과 : 저체중
#
# 이름 : 바가
# 몸무게 :  82
# 키 :  178
#
# BMI : 0.002588057063502083
# 결과 : 저체중
#
# 이름 : 가하
# 몸무게 :  70
# 키 :  145
#
# BMI : 0.0033293697978596906
# 결과 : 저체중
#
# 이름 : 파라
# 몸무게 :  66
# 키 :  145
#
# BMI : 0.003139120095124851
# 결과 : 저체중
#
# 이름 : 다라
# 몸무게 :  98
# 키 :  161
#
# BMI : 0.003780718336483932
# 결과 : 저체중
#
# 이름 : 차차
# 몸무게 :  63
# 키 :  167
#
# BMI : 0.0022589551436050055
# 결과 : 저체중
#
# 이름 : 라차
# 몸무게 :  98
# 키 :  143
#
# BMI : 0.004792410386815982
# 결과 : 저체중
#
# 이름 : 바마
# 몸무게 :  92
# 키 :  160
#
# BMI : 0.00359375
# 결과 : 저체중
#
# 이름 : 나바
# 몸무게 :  93
# 키 :  195
#
# BMI : 0.002445759368836292
# 결과 : 저체중
#
# 이름 : 마타
# 몸무게 :  86
# 키 :  179
#
# BMI : 0.0026840610467838083
# 결과 : 저체중
#
# 이름 : 아가
# 몸무게 :  99
# 키 :  151
#
# BMI : 0.0043419148282970044
# 결과 : 저체중
#
# 이름 : 사마
# 몸무게 :  72
# 키 :  148
#
# BMI : 0.003287070854638422
# 결과 : 저체중
#
# 이름 : 라카
# 몸무게 :  45
# 키 :  156
#
# BMI : 0.0018491124260355029
# 결과 : 저체중
#
# 이름 : 다하
# 몸무게 :  78
# 키 :  184
#
# BMI : 0.002303875236294896
# 결과 : 저체중
#
# 이름 : 차카
# 몸무게 :  40
# 키 :  145
#
# BMI : 0.0019024970273483948
# 결과 : 저체중
#
# 이름 : 차아
# 몸무게 :  51
# 키 :  196
#
# BMI : 0.0013275718450645564
# 결과 : 저체중
#
# 이름 : 다자
# 몸무게 :  93
# 키 :  159
#
# BMI : 0.0036786519520588586
# 결과 : 저체중
#
# 이름 : 마타
# 몸무게 :  67
# 키 :  195
#
# BMI : 0.001761998685075608
# 결과 : 저체중
#
# 이름 : 타나
# 몸무게 :  72
# 키 :  177
#
# BMI : 0.002298190175237001
# 결과 : 저체중
#
# 이름 : 사차
# 몸무게 :  74
# 키 :  159
#
# BMI : 0.0029270994027135004
# 결과 : 저체중
#
# 이름 : 마다
# 몸무게 :  71
# 키 :  140
#
# BMI : 0.003622448979591837
# 결과 : 저체중
#
# 이름 : 나파
# 몸무게 :  78
# 키 :  170
#
# BMI : 0.002698961937716263
# 결과 : 저체중
#
# 이름 : 가자
# 몸무게 :  60
# 키 :  148
#
# BMI : 0.002739225712198685
# 결과 : 저체중
#
# 이름 : 파나
# 몸무게 :  68
# 키 :  187
#
# BMI : 0.0019445794846864365
# 결과 : 저체중
#
# 이름 : 카자
# 몸무게 :  42
# 키 :  160
#
# BMI : 0.001640625
# 결과 : 저체중
#
# 이름 : 마카
# 몸무게 :  60
# 키 :  159
#
# BMI : 0.0023733238400379733
# 결과 : 저체중
#
# 이름 : 라차
# 몸무게 :  88
# 키 :  150
#
# BMI : 0.003911111111111111
# 결과 : 저체중
#
# 이름 : 파자
# 몸무게 :  67
# 키 :  161
#
# BMI : 0.002584776821881872
# 결과 : 저체중
#
# 이름 : 사다
# 몸무게 :  94
# 키 :  150
#
# BMI : 0.004177777777777778
# 결과 : 저체중
#
# 이름 : 차다
# 몸무게 :  69
# 키 :  187
#
# BMI : 0.001973176241814178
# 결과 : 저체중
#
# 이름 : 자나
# 몸무게 :  73
# 키 :  155
#
# BMI : 0.0030385015608740897
# 결과 : 저체중
#
# 이름 : 사차
# 몸무게 :  70
# 키 :  187
#
# BMI : 0.00200177299894192
# 결과 : 저체중
#
# 이름 : 차차
# 몸무게 :  63
# 키 :  148
#
# BMI : 0.0028761869978086193
# 결과 : 저체중
#
# 이름 : 하카
# 몸무게 :  41
# 키 :  175
#
# BMI : 0.0013387755102040816
# 결과 : 저체중
#
# 이름 : 가자
# 몸무게 :  46
# 키 :  192
#
# BMI : 0.001247829861111111
# 결과 : 저체중
#
# 이름 : 자아
# 몸무게 :  67
# 키 :  170
#
# BMI : 0.0023183391003460205
# 결과 : 저체중
#
# 이름 : 타하
# 몸무게 :  54
# 키 :  192
#
# BMI : 0.00146484375
# 결과 : 저체중
#
# 이름 : 라가
# 몸무게 :  45
# 키 :  188
#
# BMI : 0.0012732005432322317
# 결과 : 저체중
#
# 이름 : 하바
# 몸무게 :  82
# 키 :  190
#
# BMI : 0.002271468144044321
# 결과 : 저체중
#
# 이름 : 파라
# 몸무게 :  93
# 키 :  193
#
# BMI : 0.0024967113211092915
# 결과 : 저체중
#
# 이름 : 카자
# 몸무게 :  80
# 키 :  195
#
# BMI : 0.00210387902695595
# 결과 : 저체중
#
# 이름 : 아마
# 몸무게 :  42
# 키 :  142
#
# BMI : 0.002082920055544535
# 결과 : 저체중
#
# 이름 : 마가
# 몸무게 :  58
# 키 :  176
#
# BMI : 0.0018724173553719009
# 결과 : 저체중
#
# 이름 : 파차
# 몸무게 :  56
# 키 :  173
#
# BMI : 0.0018710949246550168
# 결과 : 저체중
#
# 이름 : 나차
# 몸무게 :  53
# 키 :  180
#
# BMI : 0.0016358024691358025
# 결과 : 저체중
#
# 이름 : 나카
# 몸무게 :  67
# 키 :  191
#
# BMI : 0.0018365724623776762
# 결과 : 저체중
#
# 이름 : 차하
# 몸무게 :  93
# 키 :  145
#
# BMI : 0.004423305588585018
# 결과 : 저체중
#
# 이름 : 라차
# 몸무게 :  80
# 키 :  193
#
# BMI : 0.002147708663319821
# 결과 : 저체중
#
# 이름 : 차타
# 몸무게 :  63
# 키 :  148
#
# BMI : 0.0028761869978086193
# 결과 : 저체중
#
# 이름 : 타타
# 몸무게 :  63
# 키 :  157
#
# BMI : 0.0025558846200657227
# 결과 : 저체중
#
# 이름 : 바바
# 몸무게 :  81
# 키 :  175
#
# BMI : 0.0026448979591836737
# 결과 : 저체중
#
# 이름 : 하아
# 몸무게 :  88
# 키 :  152
#
# BMI : 0.003808864265927978
# 결과 : 저체중
#
# 이름 : 바하
# 몸무게 :  75
# 키 :  197
#
# BMI : 0.0019325414208044526
# 결과 : 저체중
#
# 이름 : 가사
# 몸무게 :  62
# 키 :  145
#
# BMI : 0.0029488703923900117
# 결과 : 저체중
#
# 이름 : 다차
# 몸무게 :  64
# 키 :  167
#
# BMI : 0.0022948115744558786
# 결과 : 저체중
#
# 이름 : 하라
# 몸무게 :  80
# 키 :  174
#
# BMI : 0.002642356982428326
# 결과 : 저체중
#
# 이름 : 타하
# 몸무게 :  66
# 키 :  162
#
# BMI : 0.002514860539551898
# 결과 : 저체중
#
# 이름 : 다마
# 몸무게 :  96
# 키 :  195
#
# BMI : 0.00252465483234714
# 결과 : 저체중
#
# 이름 : 파바
# 몸무게 :  65
# 키 :  175
#
# BMI : 0.0021224489795918368
# 결과 : 저체중
#
# 이름 : 마나
# 몸무게 :  67
# 키 :  152
#
# BMI : 0.0028999307479224377
# 결과 : 저체중
#
# 이름 : 바사
# 몸무게 :  97
# 키 :  152
#
# BMI : 0.004198407202216066
# 결과 : 저체중
#
# 이름 : 타나
# 몸무게 :  50
# 키 :  173
#
# BMI : 0.0016706204684419793
# 결과 : 저체중
#
# 이름 : 아자
# 몸무게 :  84
# 키 :  149
#
# BMI : 0.0037836133507499663
# 결과 : 저체중
#
# 이름 : 라바
# 몸무게 :  85
# 키 :  178
#
# BMI : 0.0026827420780204518
# 결과 : 저체중
#
# 이름 : 카자
# 몸무게 :  98
# 키 :  162
#
# BMI : 0.0037341868617588782
# 결과 : 저체중
#
# 이름 : 사사
# 몸무게 :  47
# 키 :  143
#
# BMI : 0.0022984008997995013
# 결과 : 저체중
#
# 이름 : 파아
# 몸무게 :  82
# 키 :  146
#
# BMI : 0.0038468755864139613
# 결과 : 저체중
#
# 이름 : 카차
# 몸무게 :  40
# 키 :  173
#
# BMI : 0.0013364963747535836
# 결과 : 저체중
#
# 이름 : 바사
# 몸무게 :  41
# 키 :  156
#
# BMI : 0.0016847468770545694
# 결과 : 저체중
#
# 이름 : 하나
# 몸무게 :  79
# 키 :  196
#
# BMI : 0.0020564348188254894
# 결과 : 저체중
#
# 이름 : 라아
# 몸무게 :  40
# 키 :  177
#
# BMI : 0.0012767723195761117
# 결과 : 저체중
#
# 이름 : 나아
# 몸무게 :  91
# 키 :  158
#
# BMI : 0.0036452491587886555
# 결과 : 저체중
#
# 이름 : 카바
# 몸무게 :  84
# 키 :  194
#
# BMI : 0.002231905622276544
# 결과 : 저체중
#
# 이름 : 마라
# 몸무게 :  91
# 키 :  185
#
# BMI : 0.002658875091307524
# 결과 : 저체중
#
# 이름 : 다가
# 몸무게 :  65
# 키 :  147
#
# BMI : 0.0030080059234578187
# 결과 : 저체중
#
# 이름 : 가아
# 몸무게 :  53
# 키 :  144
#
# BMI : 0.0025559413580246914
# 결과 : 저체중
#
# 이름 : 라하
# 몸무게 :  82
# 키 :  145
#
# BMI : 0.003900118906064209
# 결과 : 저체중
#
# 이름 : 마가
# 몸무게 :  53
# 키 :  163
#
# BMI : 0.001994805976890361
# 결과 : 저체중
#
# 이름 : 아자
# 몸무게 :  55
# 키 :  193
#
# BMI : 0.0014765497060323766
# 결과 : 저체중
#
# 이름 : 가아
# 몸무게 :  42
# 키 :  152
#
# BMI : 0.0018178670360110803
# 결과 : 저체중
#
# 이름 : 사아
# 몸무게 :  66
# 키 :  159
#
# BMI : 0.0026106562240417706
# 결과 : 저체중
#
# 이름 : 바하
# 몸무게 :  69
# 키 :  194
#
# BMI : 0.001833351046870018
# 결과 : 저체중
#
# 이름 : 카아
# 몸무게 :  95
# 키 :  191
#
# BMI : 0.0026040952824758095
# 결과 : 저체중
#
# 이름 : 사카
# 몸무게 :  98
# 키 :  173
#
# BMI : 0.0032744161181462797
# 결과 : 저체중
#
# 이름 : 다아
# 몸무게 :  59
# 키 :  190
#
# BMI : 0.0016343490304709142
# 결과 : 저체중
#
# 이름 : 나다
# 몸무게 :  89
# 키 :  176
#
# BMI : 0.0028731921487603305
# 결과 : 저체중
#
# 이름 : 사사
# 몸무게 :  88
# 키 :  177
#
# BMI : 0.0028088991030674453
# 결과 : 저체중
#
# 이름 : 사카
# 몸무게 :  57
# 키 :  144
#
# BMI : 0.0027488425925925927
# 결과 : 저체중
#
# 이름 : 바바
# 몸무게 :  81
# 키 :  166
#
# BMI : 0.00293946871824648
# 결과 : 저체중
#
# 이름 : 사파
# 몸무게 :  92
# 키 :  140
#
# BMI : 0.004693877551020408
# 결과 : 저체중
#
# 이름 : 차나
# 몸무게 :  97
# 키 :  166
#
# BMI : 0.0035201045144433152
# 결과 : 저체중
#
# 이름 : 사아
# 몸무게 :  91
# 키 :  151
#
# BMI : 0.003991053023990176
# 결과 : 저체중
#
# 이름 : 마하
# 몸무게 :  69
# 키 :  191
#
# BMI : 0.0018913955209561141
# 결과 : 저체중
#
# 이름 : 파카
# 몸무게 :  49
# 키 :  175
#
# BMI : 0.0016
# 결과 : 저체중
#
# 이름 : 파카
# 몸무게 :  84
# 키 :  171
#
# BMI : 0.0028726787729557814
# 결과 : 저체중
#
# 이름 : 다라
# 몸무게 :  55
# 키 :  169
#
# BMI : 0.0019257028815517663
# 결과 : 저체중
#
# 이름 : 파타
# 몸무게 :  76
# 키 :  174
#
# BMI : 0.00251023913330691
# 결과 : 저체중
#
# 이름 : 파파
# 몸무게 :  72
# 키 :  183
#
# BMI : 0.002149959688255845
# 결과 : 저체중
#
# 이름 : 마아
# 몸무게 :  60
# 키 :  193
#
# BMI : 0.0016107814974898654
# 결과 : 저체중
#
# 이름 : 가사
# 몸무게 :  87
# 키 :  184
#
# BMI : 0.0025697069943289223
# 결과 : 저체중
#
# 이름 : 자카
# 몸무게 :  72
# 키 :  165
#
# BMI : 0.002644628099173554
# 결과 : 저체중
#
# 이름 : 자다
# 몸무게 :  80
# 키 :  199
#
# BMI : 0.00202015100628772
# 결과 : 저체중
#
# 이름 : 라사
# 몸무게 :  43
# 키 :  183
#
# BMI : 0.001284003702708352
# 결과 : 저체중
#
# 이름 : 라가
# 몸무게 :  52
# 키 :  149
#
# BMI : 0.0023422368361785506
# 결과 : 저체중
#
# 이름 : 하나
# 몸무게 :  73
# 키 :  197
#
# BMI : 0.0018810069829163338
# 결과 : 저체중
#
# 이름 : 사라
# 몸무게 :  99
# 키 :  181
#
# BMI : 0.0030218857788223805
# 결과 : 저체중
#
# 이름 : 라다
# 몸무게 :  56
# 키 :  181
#
# BMI : 0.0017093495314550837
# 결과 : 저체중
#
# 이름 : 카카
# 몸무게 :  41
# 키 :  192
#
# BMI : 0.0011121961805555555
# 결과 : 저체중
#
# 이름 : 사하
# 몸무게 :  67
# 키 :  189
#
# BMI : 0.001875647378292881
# 결과 : 저체중
#
# 이름 : 아나
# 몸무게 :  65
# 키 :  160
#
# BMI : 0.0025390625
# 결과 : 저체중
#
# 이름 : 파아
# 몸무게 :  68
# 키 :  199
#
# BMI : 0.001717128355344562
# 결과 : 저체중
#
# 이름 : 마카
# 몸무게 :  77
# 키 :  158
#
# BMI : 0.0030844415958980933
# 결과 : 저체중
#
# 이름 : 가카
# 몸무게 :  48
# 키 :  155
#
# BMI : 0.0019979188345473466
# 결과 : 저체중
#
# 이름 : 다다
# 몸무게 :  94
# 키 :  169
#
# BMI : 0.0032912012884702916
# 결과 : 저체중
#
# 이름 : 다다
# 몸무게 :  58
# 키 :  166
#
# BMI : 0.002104804761213529
# 결과 : 저체중
#
# 이름 : 하바
# 몸무게 :  89
# 키 :  171
#
# BMI : 0.003043671557060292
# 결과 : 저체중
#
# 이름 : 바하
# 몸무게 :  53
# 키 :  190
#
# BMI : 0.0014681440443213296
# 결과 : 저체중
#
# 이름 : 사카
# 몸무게 :  58
# 키 :  144
#
# BMI : 0.0027970679012345677
# 결과 : 저체중
#
# 이름 : 나가
# 몸무게 :  81
# 키 :  194
#
# BMI : 0.0021521947071952386
# 결과 : 저체중
#
# 이름 : 라파
# 몸무게 :  52
# 키 :  183
#
# BMI : 0.0015527486637403327
# 결과 : 저체중
#
# 이름 : 차파
# 몸무게 :  86
# 키 :  182
#
# BMI : 0.0025963047941069918
# 결과 : 저체중
#
# 이름 : 차마
# 몸무게 :  56
# 키 :  167
#
# BMI : 0.0020079601276488937
# 결과 : 저체중
#
# 이름 : 하다
# 몸무게 :  78
# 키 :  161
#
# BMI : 0.0030091431657729255
# 결과 : 저체중
#
# 이름 : 마라
# 몸무게 :  52
# 키 :  165
#
# BMI : 0.0019100091827364554
# 결과 : 저체중
#
# 이름 : 파사
# 몸무게 :  72
# 키 :  168
#
# BMI : 0.002551020408163265
# 결과 : 저체중
#
# 이름 : 마바
# 몸무게 :  85
# 키 :  161
#
# BMI : 0.003279194475521778
# 결과 : 저체중
#
# 이름 : 타파
# 몸무게 :  45
# 키 :  185
#
# BMI : 0.001314828341855369
# 결과 : 저체중
#
# 이름 : 차다
# 몸무게 :  95
# 키 :  158
#
# BMI : 0.003805479891043102
# 결과 : 저체중
#
# 이름 : 라바
# 몸무게 :  94
# 키 :  168
#
# BMI : 0.003330498866213152
# 결과 : 저체중
#
# 이름 : 나다
# 몸무게 :  90
# 키 :  178
#
# BMI : 0.002840550435551067
# 결과 : 저체중
#
# 이름 : 가하
# 몸무게 :  78
# 키 :  168
#
# BMI : 0.0027636054421768708
# 결과 : 저체중
#
# 이름 : 차라
# 몸무게 :  51
# 키 :  164
#
# BMI : 0.001896192742415229
# 결과 : 저체중
#
# 이름 : 파파
# 몸무게 :  96
# 키 :  151
#
# BMI : 0.004210341651681944
# 결과 : 저체중
#
# 이름 : 가다
# 몸무게 :  75
# 키 :  187
#
# BMI : 0.0021447567845806286
# 결과 : 저체중
#
# 이름 : 다파
# 몸무게 :  98
# 키 :  142
#
# BMI : 0.004860146796270581
# 결과 : 저체중
#
# 이름 : 자자
# 몸무게 :  50
# 키 :  177
#
# BMI : 0.0015959653994701394
# 결과 : 저체중
#
# 이름 : 바다
# 몸무게 :  52
# 키 :  192
#
# BMI : 0.0014105902777777778
# 결과 : 저체중
#
# 이름 : 가차
# 몸무게 :  87
# 키 :  157
#
# BMI : 0.0035295549515193315
# 결과 : 저체중
#
# 이름 : 차사
# 몸무게 :  59
# 키 :  153
#
# BMI : 0.002520398137468495
# 결과 : 저체중
#
# 이름 : 카다
# 몸무게 :  95
# 키 :  169
#
# BMI : 0.0033262140681348694
# 결과 : 저체중
#
# 이름 : 나나
# 몸무게 :  49
# 키 :  157
#
# BMI : 0.0019879102600511176
# 결과 : 저체중
#
# 이름 : 파아
# 몸무게 :  67
# 키 :  156
#
# BMI : 0.0027531229454306376
# 결과 : 저체중
#
# 이름 : 다나
# 몸무게 :  95
# 키 :  152
#
# BMI : 0.004111842105263158
# 결과 : 저체중
#
# 이름 : 마하
# 몸무게 :  60
# 키 :  164
#
# BMI : 0.00223081499107674
# 결과 : 저체중
#
# 이름 : 사하
# 몸무게 :  73
# 키 :  151
#
# BMI : 0.0032016139642998113
# 결과 : 저체중
#
# 이름 : 라자
# 몸무게 :  52
# 키 :  149
#
# BMI : 0.0023422368361785506
# 결과 : 저체중
#
# 이름 : 타다
# 몸무게 :  90
# 키 :  177
#
# BMI : 0.002872737719046251
# 결과 : 저체중
#
# 이름 : 라차
# 몸무게 :  82
# 키 :  187
#
# BMI : 0.0023449340844748207
# 결과 : 저체중
#
# 이름 : 마나
# 몸무게 :  83
# 키 :  179
#
# BMI : 0.002590431010268094
# 결과 : 저체중
#
# 이름 : 파가
# 몸무게 :  58
# 키 :  142
#
# BMI : 0.002876413410037691
# 결과 : 저체중
#
# 이름 : 차파
# 몸무게 :  60
# 키 :  186
#
# BMI : 0.001734304543877905
# 결과 : 저체중
#
# 이름 : 라자
# 몸무게 :  66
# 키 :  166
#
# BMI : 0.0023951226593119466
# 결과 : 저체중
#
# 이름 : 타사
# 몸무게 :  63
# 키 :  151
#
# BMI : 0.0027630367089162755
# 결과 : 저체중
#
# 이름 : 라라
# 몸무게 :  50
# 키 :  175
#
# BMI : 0.0016326530612244899
# 결과 : 저체중
#
# 이름 : 아자
# 몸무게 :  72
# 키 :  195
#
# BMI : 0.001893491124260355
# 결과 : 저체중
#
# 이름 : 가하
# 몸무게 :  87
# 키 :  163
#
# BMI : 0.0032744928299898377
# 결과 : 저체중
#
# 이름 : 아사
# 몸무게 :  78
# 키 :  187
#
# BMI : 0.0022305470559638536
# 결과 : 저체중
#
# 이름 : 하나
# 몸무게 :  78
# 키 :  173
#
# BMI : 0.002606167930769488
# 결과 : 저체중
#
# 이름 : 자카
# 몸무게 :  63
# 키 :  154
#
# BMI : 0.002656434474616293
# 결과 : 저체중
#
# 이름 : 하카
# 몸무게 :  62
# 키 :  142
#
# BMI : 0.00307478674866098
# 결과 : 저체중
#
# 이름 : 가가
# 몸무게 :  78
# 키 :  192
#
# BMI : 0.0021158854166666665
# 결과 : 저체중
#
# 이름 : 마카
# 몸무게 :  68
# 키 :  142
#
# BMI : 0.0033723467565959135
# 결과 : 저체중
#
# 이름 : 카바
# 몸무게 :  96
# 키 :  146
#
# BMI : 0.004503659223118784
# 결과 : 저체중
#
# 이름 : 다라
# 몸무게 :  64
# 키 :  197
#
# BMI : 0.0016491020124197995
# 결과 : 저체중
#
# 이름 : 라사
# 몸무게 :  92
# 키 :  186
#
# BMI : 0.0026592669672794544
# 결과 : 저체중
#
# 이름 : 하가
# 몸무게 :  52
# 키 :  157
#
# BMI : 0.002109619051482819
# 결과 : 저체중
#
# 이름 : 차하
# 몸무게 :  43
# 키 :  152
#
# BMI : 0.0018611495844875346
# 결과 : 저체중
#
# 이름 : 자타
# 몸무게 :  73
# 키 :  193
#
# BMI : 0.0019597841552793363
# 결과 : 저체중
#
# 이름 : 카아
# 몸무게 :  83
# 키 :  165
#
# BMI : 0.003048668503213958
# 결과 : 저체중
#
# 이름 : 라파
# 몸무게 :  98
# 키 :  173
#
# BMI : 0.0032744161181462797
# 결과 : 저체중
#
# 이름 : 카타
# 몸무게 :  48
# 키 :  171
#
# BMI : 0.0016415307274033036
# 결과 : 저체중
#
# 이름 : 사하
# 몸무게 :  89
# 키 :  185
#
# BMI : 0.0026004382761139516
# 결과 : 저체중
#
# 이름 : 라나
# 몸무게 :  86
# 키 :  162
#
# BMI : 0.0032769394909312605
# 결과 : 저체중
#
# 이름 : 아아
# 몸무게 :  66
# 키 :  171
#
# BMI : 0.0022571047501795424
# 결과 : 저체중
#
# 이름 : 바타
# 몸무게 :  71
# 키 :  173
#
# BMI : 0.0023722810651876105
# 결과 : 저체중
#
# 이름 : 타차
# 몸무게 :  97
# 키 :  186
#
# BMI : 0.0028037923459359464
# 결과 : 저체중
#
# 이름 : 마마
# 몸무게 :  88
# 키 :  154
#
# BMI : 0.0037105751391465678
# 결과 : 저체중
#
# 이름 : 바가
# 몸무게 :  88
# 키 :  147
#
# BMI : 0.004072377250219816
# 결과 : 저체중
#
# 이름 : 타나
# 몸무게 :  40
# 키 :  147
#
# BMI : 0.0018510805682817346
# 결과 : 저체중
#
# 이름 : 카파
# 몸무게 :  52
# 키 :  183
#
# BMI : 0.0015527486637403327
# 결과 : 저체중
#
# 이름 : 아가
# ...
# 결과 : 저체중
#
# 이름 : 파라
# 몸무게 :  63
# 키 :  168
#
# BMI : 0.002232142857142857
# 결과 : 저체중
#
# 이름 : 자다
# 몸무게 :  88
# 키 :  153
#
# BMI : 0.0037592378999530096
# 결과 : 저체중
#
# 이름 : 나하
# 몸무게 :  59
# 키 :  191
#
# BMI : 0.0016172802280639237
# 결과 : 저체중
#
# 이름 : 자파
# 몸무게 :  76
# 키 :  145
#
# BMI : 0.00361474435196195
# 결과 : 저체중
#
# 이름 : 자하
# 몸무게 :  54
# 키 :  155
#
# BMI : 0.002247658688865765
# 결과 : 저체중
#
# 이름 : 사가
# 몸무게 :  97
# 키 :  183
#
# BMI : 0.002896473468900236
# 결과 : 저체중
#
# 이름 : 라가
# 몸무게 :  53
# 키 :  141
#
# BMI : 0.0026658618781751423
# 결과 : 저체중
#
# 이름 : 카사
# 몸무게 :  54
# 키 :  183
#
# BMI : 0.0016124697661918839
# 결과 : 저체중
#
# 이름 : 자아
# 몸무게 :  91
# 키 :  165
#
# BMI : 0.003342516069788797
# 결과 : 저체중
#
# 이름 : 다라
# 몸무게 :  60
# 키 :  154
#
# BMI : 0.0025299375948726597
# 결과 : 저체중
#
# 이름 : 가타
# 몸무게 :  58
# 키 :  143
#
# BMI : 0.002836324514646193
# 결과 : 저체중
#
# 이름 : 가카
# 몸무게 :  95
# 키 :  153
#
# BMI : 0.004058268187449272
# 결과 : 저체중
#
# 이름 : 차나
# 몸무게 :  69
# 키 :  168
#
# BMI : 0.0024447278911564627
# 결과 : 저체중
#
# 이름 : 자라
# 몸무게 :  80
# 키 :  147
#
# BMI : 0.003702161136563469
# 결과 : 저체중
#
# 이름 : 사하
# 몸무게 :  53
# 키 :  141
#
# BMI : 0.0026658618781751423
# 결과 : 저체중
#
# 이름 : 카하
# 몸무게 :  95
# 키 :  140
#
# BMI : 0.004846938775510204
# 결과 : 저체중
#
# 이름 : 라자
# 몸무게 :  66
# 키 :  154
#
# BMI : 0.0027829313543599257
# 결과 : 저체중
#
# 이름 : 가카
# 몸무게 :  90
# 키 :  182
#
# BMI : 0.002717063156623596
# 결과 : 저체중
#
# 이름 : 라마
# 몸무게 :  78
# 키 :  192
#
# BMI : 0.0021158854166666665
# 결과 : 저체중
#
# 이름 : 카가
# 몸무게 :  42
# 키 :  171
#
# BMI : 0.0014363393864778907
# 결과 : 저체중
#
# 이름 : 파자
# 몸무게 :  61
# 키 :  158
#
# BMI : 0.0024435186668803075
# 결과 : 저체중
#
# 이름 : 라아
# 몸무게 :  98
# 키 :  158
#
# BMI : 0.003925652940233937
# 결과 : 저체중
#
# 이름 : 하가
# 몸무게 :  58
# 키 :  154
#
# BMI : 0.0024456063417102377
# 결과 : 저체중
#
# 이름 : 차바
# 몸무게 :  48
# 키 :  140
#
# BMI : 0.0024489795918367346
# 결과 : 저체중
#
# 이름 : 차가
# 몸무게 :  97
# 키 :  141
#
# BMI : 0.004879030229867713
# 결과 : 저체중
#
# 이름 : 다바
# 몸무게 :  99
# 키 :  162
#
# BMI : 0.0037722908093278463
# 결과 : 저체중
#
# 이름 : 바카
# 몸무게 :  75
# 키 :  187
#
# BMI : 0.0021447567845806286
# 결과 : 저체중
#
# 이름 : 다파
# 몸무게 :  69
# 키 :  152
#
# BMI : 0.0029864958448753464
# 결과 : 저체중
#
# 이름 : 다라
# 몸무게 :  49
# 키 :  175
#
# BMI : 0.0016
# 결과 : 저체중
#
# 이름 : 다사
# 몸무게 :  62
# 키 :  159
#
# BMI : 0.0024524346347059058
# 결과 : 저체중
#
# 이름 : 사라
# 몸무게 :  51
# 키 :  177
#
# BMI : 0.0016278847074595424
# 결과 : 저체중
#
# 이름 : 라차
# 몸무게 :  80
# 키 :  144
#
# BMI : 0.0038580246913580245
# 결과 : 저체중
#
# 이름 : 하아
# 몸무게 :  53
# 키 :  195
#
# BMI : 0.0013938198553583169
# 결과 : 저체중
#
# 이름 : 바아
# 몸무게 :  62
# 키 :  179
#
# BMI : 0.0019350207546580942
# 결과 : 저체중
#
# 이름 : 카바
# 몸무게 :  95
# 키 :  163
#
# BMI : 0.0035755956189544207
# 결과 : 저체중
#
# 이름 : 타다
# 몸무게 :  89
# 키 :  166
#
# BMI : 0.0032297866163448975
# 결과 : 저체중
#
# 이름 : 카아
# 몸무게 :  56
# 키 :  191
#
# BMI : 0.0015350456401962665
# 결과 : 저체중
#
# 이름 : 아사
# 몸무게 :  87
# 키 :  141
#
# BMI : 0.0043760374226648555
# 결과 : 저체중
#
# 이름 : 차하
# 몸무게 :  72
# 키 :  147
#
# BMI : 0.003331945022907122
# 결과 : 저체중
#
# 이름 : 바자
# 몸무게 :  99
# 키 :  188
#
# BMI : 0.00280104119511091
# 결과 : 저체중
#
# 이름 : 아사
# 몸무게 :  98
# 키 :  188
#
# BMI : 0.0027727478497057492
# 결과 : 저체중
#
# 이름 : 카가
# 몸무게 :  79
# 키 :  178
#
# BMI : 0.002493372048983714
# 결과 : 저체중
#
# 이름 : 사자
# 몸무게 :  63
# 키 :  167
#
# BMI : 0.0022589551436050055
# 결과 : 저체중
#
# 이름 : 차아
# 몸무게 :  94
# 키 :  193
#
# BMI : 0.002523557679400789
# 결과 : 저체중
#
# 이름 : 파사
# 몸무게 :  91
# 키 :  188
#
# BMI : 0.0025746944318696245
# 결과 : 저체중
#
# 이름 : 다마
# 몸무게 :  68
# 키 :  163
#
# BMI : 0.0025593737061989537
# 결과 : 저체중
#
# 이름 : 사가
# 몸무게 :  48
# 키 :  184
#
# BMI : 0.0014177693761814746
# 결과 : 저체중
#
# 이름 : 아자
# 몸무게 :  47
# 키 :  186
#
# BMI : 0.0013585385593710255
# 결과 : 저체중
#
# 이름 : 파나
# 몸무게 :  85
# 키 :  192
#
# BMI : 0.0023057725694444445
# 결과 : 저체중
#
# 이름 : 타타
# 몸무게 :  92
# 키 :  194
#
# BMI : 0.0024444680624933573
# 결과 : 저체중
#
# 이름 : 가카
# 몸무게 :  83
# 키 :  187
#
# BMI : 0.0023735308416025624
# 결과 : 저체중
#
# 이름 : 파차
# 몸무게 :  58
# 키 :  153
#
# BMI : 0.002477679524969029
# 결과 : 저체중
#
# 이름 : 차가
# 몸무게 :  75
# 키 :  154
#
# BMI : 0.003162421993590825
# 결과 : 저체중
#
# 이름 : 파마
# 몸무게 :  79
# 키 :  174
#
# BMI : 0.002609327520147972
# 결과 : 저체중
#
# 이름 : 바자
# 몸무게 :  83
# 키 :  173
#
# BMI : 0.0027732299776136856
# 결과 : 저체중
#
# 이름 : 아타
# 몸무게 :  59
# 키 :  152
#
# BMI : 0.0025536703601108032
# 결과 : 저체중
#
# 이름 : 파카
# 몸무게 :  56
# 키 :  165
#
# BMI : 0.002056932966023875
# 결과 : 저체중
#
# 이름 : 파나
# 몸무게 :  41
# 키 :  184
#
# BMI : 0.0012110113421550095
# 결과 : 저체중
#
# 이름 : 타가
# 몸무게 :  69
# 키 :  142
#
# BMI : 0.003421940091251736
# 결과 : 저체중
#
# 이름 : 타라
# 몸무게 :  68
# 키 :  146
#
# BMI : 0.0031900919497091385
# 결과 : 저체중
#
# 이름 : 하카
# 몸무게 :  50
# 키 :  151
#
# BMI : 0.002192886276917679
# 결과 : 저체중
#
# 이름 : 바라
# 몸무게 :  56
# 키 :  184
#
# BMI : 0.0016540642722117202
# 결과 : 저체중
#
# 이름 : 자마
# 몸무게 :  62
# 키 :  173
#
# BMI : 0.002071569380868054
# 결과 : 저체중
#
# 이름 : 마사
# 몸무게 :  58
# 키 :  152
#
# BMI : 0.002510387811634349
# 결과 : 저체중
#
# 이름 : 마사
# 몸무게 :  58
# 키 :  151
#
# BMI : 0.0025437480812245078
# 결과 : 저체중
#
# 이름 : 타가
# 몸무게 :  48
# 키 :  178
#
# BMI : 0.0015149602322939023
# 결과 : 저체중
#
# 이름 : 라가
# 몸무게 :  69
# 키 :  168
#
# BMI : 0.0024447278911564627
# 결과 : 저체중
#
# 이름 : 다사
# 몸무게 :  57
# 키 :  154
#
# BMI : 0.002403440715129027
# 결과 : 저체중
#
# 이름 : 바타
# 몸무게 :  56
# 키 :  163
#
# BMI : 0.0021077195227520796
# 결과 : 저체중
#
# 이름 : 마타
# 몸무게 :  45
# 키 :  190
#
# BMI : 0.0012465373961218836
# 결과 : 저체중
#
# 이름 : 나다
# 몸무게 :  62
# 키 :  189
#
# BMI : 0.001735673693345651
# 결과 : 저체중
#
# 이름 : 사마
# 몸무게 :  77
# 키 :  184
#
# BMI : 0.0022743383742911153
# 결과 : 저체중
#
# 이름 : 카자
# 몸무게 :  47
# 키 :  181
#
# BMI : 0.001434632642471231
# 결과 : 저체중
#
# 이름 : 차가
# 몸무게 :  40
# 키 :  142
#
# BMI : 0.0019837333862328904
# 결과 : 저체중
#
# 이름 : 자가
# 몸무게 :  42
# 키 :  175
#
# BMI : 0.0013714285714285714
# 결과 : 저체중
#
# 이름 : 바타
# 몸무게 :  53
# 키 :  171
#
# BMI : 0.0018125235115078143
# 결과 : 저체중
#
# 이름 : 다카
# 몸무게 :  43
# 키 :  140
#
# BMI : 0.002193877551020408
# 결과 : 저체중
#
# 이름 : 다바
# 몸무게 :  92
# 키 :  151
#
# BMI : 0.00403491074952853
# 결과 : 저체중
#
# 이름 : 다파
# 몸무게 :  71
# 키 :  157
#
# BMI : 0.0028804413972169257
# 결과 : 저체중
#
# 이름 : 다카
# 몸무게 :  64
# 키 :  143
#
# BMI : 0.003129737395471661
# 결과 : 저체중
#
# 이름 : 차하
# 몸무게 :  57
# 키 :  164
#
# BMI : 0.0021192742415229032
# 결과 : 저체중
#
# 이름 : 사가
# 몸무게 :  70
# 키 :  153
#
# BMI : 0.0029903028749626213
# 결과 : 저체중
#
# 이름 : 아하
# 몸무게 :  47
# 키 :  187
#
# BMI : 0.0013440475850038606
# 결과 : 저체중
#
# 이름 : 하아
# 몸무게 :  58
# 키 :  175
#
# BMI : 0.001893877551020408
# 결과 : 저체중
#
# 이름 : 다바
# 몸무게 :  43
# 키 :  178
#
# BMI : 0.0013571518747632874
# 결과 : 저체중
#
# 이름 : 차하
# 몸무게 :  73
# 키 :  188
#
# BMI : 0.0020654142145767316
# 결과 : 저체중
#
# 이름 : 라타
# 몸무게 :  84
# 키 :  167
#
# BMI : 0.003011940191473341
# 결과 : 저체중
#
# 이름 : 나사
# 몸무게 :  91
# 키 :  167
#
# BMI : 0.0032629352074294523
# 결과 : 저체중
#
# 이름 : 라나
# 몸무게 :  62
# 키 :  174
#
# BMI : 0.0020478266613819527
# 결과 : 저체중
#
# 이름 : 라카
# 몸무게 :  86
# 키 :  143
#
# BMI : 0.004205584625165045
# 결과 : 저체중
#
# 이름 : 자다
# 몸무게 :  91
# 키 :  151
#
# BMI : 0.003991053023990176
# 결과 : 저체중
#
# 이름 : 가하
# 몸무게 :  40
# 키 :  152
#
# BMI : 0.0017313019390581717
# 결과 : 저체중
#
# 이름 : 사카
# 몸무게 :  79
# 키 :  178
#
# BMI : 0.002493372048983714
# 결과 : 저체중
#
# 이름 : 다자
# 몸무게 :  86
# 키 :  163
#
# BMI : 0.003236854981369265
# 결과 : 저체중
#
# 이름 : 다파
# 몸무게 :  75
# 키 :  170
#
# BMI : 0.0025951557093425604
# 결과 : 저체중
#
# 이름 : 바자
# 몸무게 :  53
# 키 :  189
#
# BMI : 0.0014837210604406372
# 결과 : 저체중
#
# 이름 : 마파
# 몸무게 :  76
# 키 :  192
#
# BMI : 0.0020616319444444445
# 결과 : 저체중
#
# 이름 : 가차
# 몸무게 :  54
# 키 :  149
#
# BMI : 0.002432322868339264
# 결과 : 저체중
#
# 이름 : 파하
# 몸무게 :  54
# 키 :  178
#
# BMI : 0.00170433026133064
# 결과 : 저체중
#
# 이름 : 라마
# 몸무게 :  93
# 키 :  176
#
# BMI : 0.0030023243801652892
# 결과 : 저체중
#
# 이름 : 바하
# 몸무게 :  51
# 키 :  163
#
# BMI : 0.0019195302796492153
# 결과 : 저체중
#
# 이름 : 가나
# 몸무게 :  50
# 키 :  190
#
# BMI : 0.0013850415512465374
# 결과 : 저체중
#
# 이름 : 카사
# 몸무게 :  70
# 키 :  149
#
# BMI : 0.0031530111256249716
# 결과 : 저체중
#
# 이름 : 바사
# 몸무게 :  46
# 키 :  164
#
# BMI : 0.001710291493158834
# 결과 : 저체중
#
# 이름 : 바사
# 몸무게 :  51
# 키 :  154
#
# BMI : 0.002150446955641761
# 결과 : 저체중
#
# 이름 : 타라
# 몸무게 :  48
# 키 :  146
#
# BMI : 0.002251829611559392
# 결과 : 저체중
#
# 이름 : 카아
# 몸무게 :  88
# 키 :  152
#
# BMI : 0.003808864265927978
# 결과 : 저체중
#
# 이름 : 자차
# 몸무게 :  85
# 키 :  162
#
# BMI : 0.0032388355433622925
# 결과 : 저체중
#
# 이름 : 아가
# 몸무게 :  70
# 키 :  181
#
# BMI : 0.0021366869143188546
# 결과 : 저체중
#
# 이름 : 아타
# 몸무게 :  58
# 키 :  160
#
# BMI : 0.002265625
# 결과 : 저체중
#
# 이름 : 파가
# 몸무게 :  87
# 키 :  165
#
# BMI : 0.0031955922865013774
# 결과 : 저체중
#
# 이름 : 파아
# 몸무게 :  85
# 키 :  164
#
# BMI : 0.003160321237358715
# 결과 : 저체중
#
# 이름 : 다라
# 몸무게 :  95
# 키 :  149
#
# BMI : 0.00427908652763389
# 결과 : 저체중
#
# 이름 : 하나
# 몸무게 :  92
# 키 :  188
#
# BMI : 0.002602987777274785
# 결과 : 저체중
#
# 이름 : 사마
# 몸무게 :  60
# 키 :  167
#
# BMI : 0.002151385851052386
# 결과 : 저체중
#
# 이름 : 바나
# 몸무게 :  89
# 키 :  161
#
# BMI : 0.003433509509663979
# 결과 : 저체중
#
# 이름 : 자다
# 몸무게 :  56
# 키 :  172
#
# BMI : 0.0018929150892374256
# 결과 : 저체중
#
# 이름 : 카타
# 몸무게 :  89
# 키 :  175
#
# BMI : 0.002906122448979592
# 결과 : 저체중
#
# 이름 : 하가
# 몸무게 :  92
# 키 :  147
#
# BMI : 0.0042574853070479896
# 결과 : 저체중
#
# 이름 : 카차
# 몸무게 :  59
# 키 :  145
#
# BMI : 0.0028061831153388824
# 결과 : 저체중
#
# 이름 : 마가
# 몸무게 :  58
# 키 :  193
#
# BMI : 0.00155708878090687
# 결과 : 저체중
#
# 이름 : 다다
# 몸무게 :  62
# 키 :  149
#
# BMI : 0.002792666996982118
# 결과 : 저체중
#
# 이름 : 타다
# 몸무게 :  75
# 키 :  167
#
# BMI : 0.002689232313815483
# 결과 : 저체중
#
# 이름 : 사차
# 몸무게 :  63
# 키 :  158
#
# BMI : 0.002523634033007531
# 결과 : 저체중
#
# 이름 : 바가
# 몸무게 :  89
# 키 :  185
#
# BMI : 0.0026004382761139516
# 결과 : 저체중
#
# 이름 : 마나
# 몸무게 :  71
# 키 :  177
#
# BMI : 0.002266270867247598
# 결과 : 저체중
#
# 이름 : 차타
# 몸무게 :  96
# 키 :  176
#
# BMI : 0.0030991735537190084
# 결과 : 저체중
#
# 이름 : 다카
# 몸무게 :  54
# 키 :  153
#
# BMI : 0.002306805074971165
# 결과 : 저체중
#
# 이름 : 사라
# 몸무게 :  69
# 키 :  160
#
# BMI : 0.0026953125
# 결과 : 저체중
#
# 이름 : 하마
# 몸무게 :  65
# 키 :  197
#
# BMI : 0.001674869231363859
# 결과 : 저체중
#
# 이름 : 파나
# 몸무게 :  62
# 키 :  154
#
# BMI : 0.0026142688480350817
# 결과 : 저체중
#
# 이름 : 사자
# 몸무게 :  55
# 키 :  150
#
# BMI : 0.0024444444444444444
# 결과 : 저체중
#
# 이름 : 바가
# 몸무게 :  48
# 키 :  193
#
# BMI : 0.0012886251979918925
# 결과 : 저체중
#
# 이름 : 파자
# 몸무게 :  56
# 키 :  164
#
# BMI : 0.002082093991671624
# 결과 : 저체중
#
# 이름 : 차타
# 몸무게 :  91
# 키 :  185
#
# BMI : 0.002658875091307524
# 결과 : 저체중
#
# 이름 : 차자
# 몸무게 :  48
# 키 :  185
#
# BMI : 0.0014024835646457268
# 결과 : 저체중
#
# 이름 : 바하
# 몸무게 :  80
# 키 :  183
#
# BMI : 0.00238884409806205
# 결과 : 저체중
#
# 이름 : 다다
# 몸무게 :  48
# 키 :  153
#
# BMI : 0.0020504933999743688
# 결과 : 저체중
#
# 이름 : 타아
# 몸무게 :  58
# 키 :  158
#
# BMI : 0.002323345617689473
# 결과 : 저체중
#
# 이름 : 나파
# 몸무게 :  72
# 키 :  159
#
# BMI : 0.002847988608045568
# 결과 : 저체중
#
# 이름 : 마다
# 몸무게 :  55
# 키 :  144
#
# BMI : 0.002652391975308642
# 결과 : 저체중
#
# 이름 : 자카
# 몸무게 :  81
# 키 :  145
#
# BMI : 0.0038525564803804993
# 결과 : 저체중
#
# 이름 : 자바
# 몸무게 :  90
# 키 :  184
#
# BMI : 0.0026583175803402644
# 결과 : 저체중
#
# 이름 : 타자
# 몸무게 :  64
# 키 :  191
#
# BMI : 0.001754337874510019
# 결과 : 저체중
#
# 이름 : 차나
# 몸무게 :  91
# 키 :  178
#
# BMI : 0.00287211210705719
# 결과 : 저체중
#
# 이름 : 하파
# 몸무게 :  67
# 키 :  173
#
# BMI : 0.0022386314277122524
# 결과 : 저체중
#
# 이름 : 아사
# 몸무게 :  47
# 키 :  173
#
# BMI : 0.0015703832403354606
# 결과 : 저체중
#
# 이름 : 하가
# 몸무게 :  53
# 키 :  178
#
# BMI : 0.0016727685898245172
# 결과 : 저체중
#
# 이름 : 차자
# 몸무게 :  65
# 키 :  191
#
# BMI : 0.001781749403799238
# 결과 : 저체중
#
# 이름 : 다가
# 몸무게 :  90
# 키 :  150
#
# BMI : 0.004
# 결과 : 저체중
#
# 이름 : 파자
# 몸무게 :  91
# 키 :  166
#
# BMI : 0.003302366090869502
# 결과 : 저체중
#
# 이름 : 카사
# 몸무게 :  42
# 키 :  152
#
# BMI : 0.0018178670360110803
# 결과 : 저체중
#
# 이름 : 다바
# 몸무게 :  62
# 키 :  164
#
# BMI : 0.002305175490779298
# 결과 : 저체중
#
# 이름 : 나다
# 몸무게 :  92
# 키 :  191
#
# BMI : 0.002521860694608152
# 결과 : 저체중
#
# 이름 : 사바
# 몸무게 :  46
# 키 :  188
#
# BMI : 0.0013014938886373925
# 결과 : 저체중
#
# 이름 : 다카
# 몸무게 :  63
# 키 :  162
#
# BMI : 0.0024005486968449933
# 결과 : 저체중
#
# 이름 : 가라
# 몸무게 :  99
# 키 :  187
#
# BMI : 0.0028310789556464295
# 결과 : 저체중
#
# 이름 : 파자
# 몸무게 :  93
# 키 :  198
#
# BMI : 0.0023722069176614633
# 결과 : 저체중
#
# 이름 : 마파
# 몸무게 :  75
# 키 :  167
#
# BMI : 0.002689232313815483
# 결과 : 저체중
#
# 이름 : 다하
# 몸무게 :  51
# 키 :  165
#
# BMI : 0.0018732782369146005
# 결과 : 저체중
#
# 이름 : 자아
# 몸무게 :  81
# 키 :  175
#
# BMI : 0.0026448979591836737
# 결과 : 저체중
#
# 이름 : 가차
# 몸무게 :  55
# 키 :  181
#
# BMI : 0.0016788254326791001
# 결과 : 저체중
#
# 이름 : 차자
# 몸무게 :  96
# 키 :  178
#
# BMI : 0.0030299204645878046
# 결과 : 저체중
#
# 이름 : 아라
# 몸무게 :  79
# 키 :  177
#
# BMI : 0.0025216253311628203
# 결과 : 저체중
#
# 이름 : 가다
# 몸무게 :  82
# 키 :  173
#
# BMI : 0.002739817568244846
# 결과 : 저체중
#
# 이름 : 차다
# 몸무게 :  92
# 키 :  171
#
# BMI : 0.0031462672275229986
# 결과 : 저체중
#
# 이름 : 파타
# 몸무게 :  92
# 키 :  148
#
# BMI : 0.004200146092037984
# 결과 : 저체중
#
# 이름 : 차라
# 몸무게 :  72
# 키 :  197
#
# BMI : 0.0018552397639722744
# 결과 : 저체중
#
# 이름 : 가가
# 몸무게 :  66
# 키 :  153
#
# BMI : 0.002819428424964757
# 결과 : 저체중
#
# 이름 : 사아
# 몸무게 :  63
# 키 :  176
#
# BMI : 0.0020338326446280993
# 결과 : 저체중
#
# 이름 : 다타
# 몸무게 :  51
# 키 :  195
#
# BMI : 0.0013412228796844182
# 결과 : 저체중
#
# 이름 : 마나
# 몸무게 :  60
# 키 :  192
#
# BMI : 0.0016276041666666667
# 결과 : 저체중
#
# 이름 : 타라
# 몸무게 :  55
# 키 :  143
#
# BMI : 0.0026896180742334587
# 결과 : 저체중
#
# 이름 : 카자
# 몸무게 :  70
# 키 :  168
#
# BMI : 0.00248015873015873
# 결과 : 저체중
#
# 이름 : 타차
# 몸무게 :  91
# 키 :  162
#
# BMI : 0.0034674592287761014
# 결과 : 저체중
#
# 이름 : 마자
# 몸무게 :  49
# 키 :  178
#
# BMI : 0.0015465219038000252
# 결과 : 저체중
#
# 이름 : 라사
# 몸무게 :  86
# 키 :  152
#
# BMI : 0.0037222991689750693
# 결과 : 저체중
#
# 이름 : 바차
# 몸무게 :  83
# 키 :  190
#
# BMI : 0.002299168975069252
# 결과 : 저체중
#
# 이름 : 아아
# 몸무게 :  51
# 키 :  172
#
# BMI : 0.0017239048134126554
# 결과 : 저체중
#
# 이름 : 마바
# 몸무게 :  55
# 키 :  192
#
# BMI : 0.001491970486111111
# 결과 : 저체중
#
# 이름 : 카아
# 몸무게 :  67
# 키 :  147
#
# BMI : 0.003100559951871905
# 결과 : 저체중
#
# 이름 : 마아
# 몸무게 :  95
# 키 :  199
#
# BMI : 0.0023989293199666675
# 결과 : 저체중
#
# 이름 : 자나
# 몸무게 :  43
# 키 :  193
#
# BMI : 0.0011543934065344037
# 결과 : 저체중
#
# 이름 : 아바
# 몸무게 :  57
# 키 :  142
#
# BMI : 0.0028268200753818686
# 결과 : 저체중
#
# 이름 : 차가
# 몸무게 :  46
# 키 :  198
#
# BMI : 0.001173349658198143
# 결과 : 저체중
#
# 이름 : 파라
# 몸무게 :  90
# 키 :  141
#
# BMI : 0.004526935264825713
# 결과 : 저체중
#
# 이름 : 다아
# 몸무게 :  43
# 키 :  174
#
# BMI : 0.0014202668780552252
# 결과 : 저체중
#
# 이름 : 타자
# 몸무게 :  56
# 키 :  198
#
# BMI : 0.0014284256708499133
# 결과 : 저체중
#
# 이름 : 카아
# 몸무게 :  52
# 키 :  154
#
# BMI : 0.0021926125822229717
# 결과 : 저체중
#
# 이름 : 가아
# 몸무게 :  98
# 키 :  141
#
# BMI : 0.004929329510587999
# 결과 : 저체중
#
# 이름 : 자카
# 몸무게 :  98
# 키 :  166
#
# BMI : 0.0035563942517056178
# 결과 : 저체중
#
# 이름 : 사사
# 몸무게 :  53
# 키 :  192
#
# BMI : 0.001437717013888889
# 결과 : 저체중
#
# 이름 : 차나
# 몸무게 :  46
# 키 :  180
#
# BMI : 0.001419753086419753
# 결과 : 저체중
#
# 이름 : 다바
# 몸무게 :  91
# 키 :  151
#
# BMI : 0.003991053023990176
# 결과 : 저체중
#
# 이름 : 파가
# 몸무게 :  93
# 키 :  141
#
# BMI : 0.00467783310698657
# 결과 : 저체중
#
# 이름 : 파자
# 몸무게 :  80
# 키 :  170
#
# BMI : 0.002768166089965398
# 결과 : 저체중
#
# 이름 : 나자
# 몸무게 :  71
# 키 :  159
#
# BMI : 0.0028084332107116017
# 결과 : 저체중
#
# 이름 : 자자
# 몸무게 :  77
# 키 :  160
#
# BMI : 0.0030078125
# 결과 : 저체중
#
# 이름 : 자라
# 몸무게 :  48
# 키 :  199
#
# BMI : 0.001212090603772632
# 결과 : 저체중
#
# 이름 : 다아
# 몸무게 :  44
# 키 :  164
#
# BMI : 0.001635930993456276
# 결과 : 저체중
#
# 이름 : 사다
# 몸무게 :  45
# 키 :  154
#
# BMI : 0.0018974531961544949
# 결과 : 저체중
#
# 이름 : 카자
# 몸무게 :  52
# 키 :  190
#
# BMI : 0.0014404432132963988
# 결과 : 저체중
#
# 이름 : 가자
# 몸무게 :  80
# 키 :  164
#
# BMI : 0.00297441998810232
# 결과 : 저체중
#
# 이름 : 나카
# 몸무게 :  80
# 키 :  199
#
# BMI : 0.00202015100628772
# 결과 : 저체중
#
# 이름 : 나아
# 몸무게 :  46
# 키 :  186
#
# BMI : 0.0013296334836397272
# 결과 : 저체중
#
# 이름 : 다라
# 몸무게 :  45
# 키 :  147
#
# BMI : 0.0020824656393169513
# 결과 : 저체중
#
# 이름 : 차사
# 몸무게 :  83
# 키 :  177
#
# BMI : 0.0026493025631204314
# 결과 : 저체중
#
# 이름 : 자차
# 몸무게 :  62
# 키 :  161
#
# BMI : 0.00239188302920412
# 결과 : 저체중
#
# 이름 : 다바
# 몸무게 :  92
# 키 :  141
#
# BMI : 0.004627533826266284
# 결과 : 저체중
#
# 이름 : 카카
# 몸무게 :  59
# 키 :  157
#
# BMI : 0.0023936062314901213
# 결과 : 저체중
#
# 이름 : 자차
# 몸무게 :  96
# 키 :  165
#
# BMI : 0.0035261707988980717
# 결과 : 저체중
#
# 이름 : 파카
# 몸무게 :  84
# 키 :  156
#
# BMI : 0.0034516765285996054
# 결과 : 저체중
#
# 이름 : 바자
# 몸무게 :  65
# 키 :  154
#
# BMI : 0.002740765727778715
# 결과 : 저체중
#
# 이름 : 마사
# 몸무게 :  99
# 키 :  164
#
# BMI : 0.0036808447352766212
# 결과 : 저체중
#
# 이름 : 카차
# 몸무게 :  43
# 키 :  193
#
# BMI : 0.0011543934065344037
# 결과 : 저체중
#
# 이름 : 마다
# 몸무게 :  82
# 키 :  197
#
# BMI : 0.002112911953412868
# 결과 : 저체중
#
# 이름 : 타가
# 몸무게 :  60
# 키 :  167
#
# BMI : 0.002151385851052386
# 결과 : 저체중
#
# 이름 : 나나
# 몸무게 :  86
# 키 :  177
#
# BMI : 0.00274506048708864
# 결과 : 저체중
#
# 이름 : 파타
# 몸무게 :  87
# 키 :  150
#
# BMI : 0.0038666666666666667
# 결과 : 저체중
#
# 이름 : 마나
# 몸무게 :  92
# 키 :  162
#
# BMI : 0.0035055631763450694
# 결과 : 저체중
#
# 이름 : 나아
# 몸무게 :  70
# 키 :  175
#
# BMI : 0.002285714285714286
# 결과 : 저체중
#
# 이름 : 마타
# 몸무게 :  92
# 키 :  172
#
# BMI : 0.0031097890751757705
# 결과 : 저체중
#
# 이름 : 카라
# 몸무게 :  78
# 키 :  182
#
# BMI : 0.002354788069073783
# 결과 : 저체중
#
# 이름 : 다마
# 몸무게 :  86
# 키 :  196
#
# BMI : 0.0022386505622657227
# 결과 : 저체중
#
# 이름 : 가사
# 몸무게 :  63
# 키 :  175
#
# BMI : 0.002057142857142857
# 결과 : 저체중
#
# 이름 : 하차
# 몸무게 :  73
# 키 :  198
#
# BMI : 0.0018620548923579227
# 결과 : 저체중
#
# 이름 : 하바
# 몸무게 :  73
# 키 :  166
#
# BMI : 0.002649150820148062
# 결과 : 저체중
#
# 이름 : 차차
# 몸무게 :  53
# 키 :  167
#
# BMI : 0.0019003908350962745
# 결과 : 저체중
#
# 이름 : 파사
# 몸무게 :  95
# 키 :  154
#
# BMI : 0.004005734525215045
# 결과 : 저체중
#
# 이름 : 사차
# 몸무게 :  44
# 키 :  142
#
# BMI : 0.0021821067248561795
# 결과 : 저체중
#
# 이름 : 다카
# 몸무게 :  82
# 키 :  147
#
# BMI : 0.0037947151649775556
# 결과 : 저체중
#
# 이름 : 파라
# 몸무게 :  41
# 키 :  168
#
# BMI : 0.0014526643990929705
# 결과 : 저체중
#
# 이름 : 마나
# 몸무게 :  82
# 키 :  153
#
# BMI : 0.0035029262249562133
# 결과 : 저체중
#
# 이름 : 가마
# 몸무게 :  85
# 키 :  159
#
# BMI : 0.003362208773387129
# 결과 : 저체중
#
# 이름 : 가가
# 몸무게 :  69
# 키 :  187
#
# BMI : 0.001973176241814178
# 결과 : 저체중
#
# 이름 : 카자
# 몸무게 :  56
# 키 :  199
#
# BMI : 0.001414105704401404
# 결과 : 저체중
#
# 이름 : 자사
# 몸무게 :  74
# 키 :  146
#
# BMI : 0.0034715706511540627
# 결과 : 저체중
#
# 이름 : 나다
# 몸무게 :  67
# 키 :  145
#
# BMI : 0.0031866825208085614
# 결과 : 저체중
#
# 이름 : 하바
# 몸무게 :  43
# 키 :  146
#
# BMI : 0.0020172640270219554
# 결과 : 저체중
#
# 이름 : 하아
# 몸무게 :  58
# 키 :  172
#
# BMI : 0.0019605191995673336
# 결과 : 저체중
#
# 이름 : 나사
# 몸무게 :  78
# 키 :  185
#
# BMI : 0.002279035792549306
# 결과 : 저체중
#
# 이름 : 타마
# 몸무게 :  80
# 키 :  179
#
# BMI : 0.00249680097375238
# 결과 : 저체중
#
# 이름 : 아바
# 몸무게 :  97
# 키 :  151
#
# BMI : 0.004254199377220298
# 결과 : 저체중
#
# 이름 : 마자
# 몸무게 :  43
# 키 :  152
#
# BMI : 0.0018611495844875346
# 결과 : 저체중
#
# 이름 : 타다
# 몸무게 :  58
# 키 :  152
#
# BMI : 0.002510387811634349
# 결과 : 저체중
