# %%
import os

print("현재 운영체제:", os.name)
print("현재 폴더:", os.getcwd())
print("현재 폴더 내부의 요소:", os.listdir())

os.mkdir("hello")
os.rmdir("hello")

with open("original.txt", "w") as file:
    file.write("hello")
os.rename("original.txt", "new.txt")

os.remove("new.txt")
os.system("dir")
# Out:
# 현재 운영체제: nt
# 현재 폴더: c:\Users\caqud\OneDrive\바탕 화면\studying_python
# 현재 폴더 내부의 요소: ['.git', '1 copy 38.ipynb', '1 copy 39.ipynb', '1 copy 40.ipynb', '1 copy 41.ipynb', '1 copy 42.ipynb', '1 copy 43.ipynb', '1 copy 44.ipynb', '1 copy.ipynb', '101번 3번 문제.ipynb', '101번 3번 문제.jpg', '101번 4번 문제.ipynb', '101번 4번 문제.jpg', '101번 5번 문제.ipynb', '101번 5번 문제.jpg', '111쪽 3번 문제.ipynb', '111쪽 3번 문제.jpg', '111쪽 4번 문제.ipynb', '111쪽 4번 문제.jpg', '111쪽 5번 문제.ipynb', '111쪽 5번 문제.jpg', '115쪽 원의 둘레와 넓이 구하기.ipynb', '115쪽 원의 둘레와 넓이 구하기.jpg', '120쪽 입력받고 더하기.ipynb', '120쪽 입력받고 더하기.jpg', '120쪽 입력자료형 확인.ipynb', '120쪽 입력자료형 확인.jpg', '121쪽 int()함수 활용하기.ipynb', '121쪽 int()함수 활용하기.jpg', '122쪽 int()함수와 float()함수 조합하기.ipynb', '122쪽 int()함수와 float()함수 조합하기.jpg', '122쪽 int()함수와 float()함수 활용하기.ipynb', '122쪽 int()함수와 float()함수 활용하기.jpg', '124쪽 str()함수를 사용해 숫자를 문자열로 변환하기.ipynb', '124쪽 str()함수를 사용해 숫자를 문자열로 변환하기.jpg', '125쪽 inch단위를 cm단위로 변경하기..jpg', '125쪽 inch단위를 cm단위로 변경하기.ipynb', '128p_계절구하기.ipynb', '131쪽 4번문제.ipynb', '131쪽 4번문제.jpg', '132쪽 5번문제.ipynb', '132쪽 5번문제.jpg', '132쪽 6번문제.ipynb', '132쪽 6번문제.jpg', '135쪽 format()함수로 숫자를 문자열로 변환하기.ipynb', '135쪽 format()함수로 숫자를 문자열로 변환하기.jpg', '136쪽 format()함수의 다양한 형태.ipynb', '136쪽 format()함수의 다양한 형태.jpg', '137쪽 정수를 특정 칸에 출력하기.ipynb', '137쪽 정수를 특정 칸에 출력하기.jpg', '138쪽 기호붙여 출력하기.ipynb', '138쪽 기호붙여 출력하기.jpg', '139쪽 조합해보기.ipynb', '139쪽 조합해보기.jpg', '140쪽 다양한 형태의 부동 소수점 출력하기.ipynb', '140쪽 다양한 형태의 부동 소수점 출력하기.jpg', '140쪽 소수점 아래 자릿수 지정하기.ipynb', '140쪽 소수점 아래 자릿수 지정하기.jpg', '141쪽 의미없는 소수점 제거하기.ipynb', '141쪽 의미없는 소수점 제거하기.jpg', '151쪽 3번문제.ipynb', '151쪽 3번문제.jpg', '151쪽 4번문제.ipynb', '151쪽 4번문제.jpg', '152쪽 도전문제 1번.ipynb', '152쪽 도전문제 1번.jpg', '153쪽 도전문제 2번.ipynb', '153쪽 도전문제 2번.jpg', '159쪽 not 연산자 조합하기.ipynb', '159쪽 not 연산자 조합하기.jpg', '164p_조건문의 기본 사용.ipynb', '164p_조건문의 기본 사용.jpg', '165p_날짜 시간 출력.ipynb', '165p_날짜 시간 출력.jpg', '166p_시간을 한 줄로 출력하기.ipynb', '166p_시간을 한 줄로 출력하기.jpg', '167p_계절을 구분하는 프로그램.ipynb', '167p_계절을 구분하는 프로그램.jpg', '167p_오전과 오후를 구분하는 프로그램.ipynb', '167p_오전과 오후를 구분하는 프로그램.jpg', '169p_끝자리로 짝수와 홀수 구분.ipynb', '169p_끝자리로 짝수와 홀수 구분.jpg', '170p_in문자열 연산자를 활용해서 짝수와 홀수 구분.ipynb', '170p_in문자열 연산자를 활용해서 짝수와 홀수 구분.jpg', '171p_나머지 연산자를 활용해서 짝수와 홀수 구분.ipynb', '171p_나머지 연산자를 활용해서 짝수와 홀수 구분.jpg', '177쪽 if조건문에 else 구문을 추가하여 짝수와 홀수 구분하기.ipynb', '177쪽 if조건문에 else 구문을 추가하여 짝수와 홀수 구분하기.jpg', '180쪽 유머를 조건문으로 구현하기.ipynb', '180쪽 유머를 조건문으로 구현하기.jpg', '181쪽 유머를 조건문으로 구현하기(2).ipynb', '181쪽 유머를 조건문으로 구현하기(2).jpg', '182쪽_false로 변환되는값.ipynb', '182쪽_false로 변환되는값.jpg', '183쪽 나중에하려고 비워 둔 구문.ipynb', '183쪽 나중에하려고 비워 둔 구문.jpg', '184쪽 pass키워드를 사용한 미구현 부분 입력.ipynb', '184쪽 pass키워드를 사용한 미구현 부분 입력.jpg', '186쪽 1번문제.ipynb', '186쪽 1번문제.jpg', '187쪽 2번문제.ipynb', '187쪽 2번문제.jpg', '187쪽 3번문제.ipynb', '187쪽 3번문제.jpg', '188쪽 도전문제1번.ipynb', '188쪽 도전문제1번.jpg', '189쪽 도전문제2번.ipynb', '189쪽 도전문제2번.jpg', '196쪽 리스트연산자.ipynb', '196쪽 리스트연산자.jpg', '198쪽 리스트에 요소 추가하기.ipynb', '198쪽 리스트에 요소 추가하기.jpg', '202쪽 리스트 요소 하나 제거하기.ipynb', '202쪽 리스트 요소 하나 제거하기.jpg', '209쪽 for반복문과 리스트.ipynb', '209쪽 for반복문과 리스트.jpg', '210쪽 2차원 리스트에 반복문 한번 사용하기.ipynb', '210쪽 2차원 리스트에 반복문 한번 사용하기.jpg', '211쪽 2차원 리스트에 반복문 두번 사용하기.ipynb', '211쪽 2차원 리스트에 반복문 두번 사용하기.jpg', '213p_1번문제.ipynb', '213p_1번문제.jpg', '214p_2번문제.ipynb', '214p_2번문제.jpg', '214p_3번문제.ipynb', '214p_3번문제.jpg', '215p_4번문제.ipynb', '215p_4번문제.jpg', '215p_5번문제.ipynb', '215p_5번문제.jpg', '219쪽 딕셔너리 요소에 접근하기.ipynb', '219쪽 딕셔너리 요소에 접근하기.jpg', '222쪽 딕셔너리에 요소 제거하기.ipynb', '222쪽 딕셔너리에 요소 제거하기.jpg', '222쪽 딕셔너리에 요소 추가하기.ipynb', '222쪽 딕셔너리에 요소 추가하기.jpg', '224쪽 키가 존재하는지 확인하고 값에 접근하기.ipynb', '224쪽 키가 존재하는지 확인하고 값에 접근하기.jpg', '225쪽 키가 존재하지않을 때 none을 출력하는지 확인하기.ipynb', '225쪽 키가 존재하지않을 때 none을 출력하는지 확인하기.jpg', '226쪽 for반복문과 딕셔너리.ipynb', '226쪽 for반복문과 딕셔너리.jpg', '227p_2번문제.ipynb', '227p_2번문제.jpg', '228p_3번문제.ipynb', '228p_3번문제.jpg', '229p_4번문제 .ipynb', '229p_4번문제 .jpg', '234p_for 반복문과 범위.ipynb', '234p_for 반복문과 범위.jpg', '235p_리스트의_범위를_조합해서_입력하기.ipynb', '235p_리스트의_범위를_조합해서_입력하기.jpg', '235p_반대로_반복하기(1).ipynb', '235p_반대로_반복하기(1).jpg', '236p_반대로_반복하기(2).ipynb', '236p_반대로_반복하기(2).jpg', '237p_반복문으로_피라미드_만들기(1).ipynb', '237p_반복문으로_피라미드_만들기(1).jpg', ' ...
# 0
