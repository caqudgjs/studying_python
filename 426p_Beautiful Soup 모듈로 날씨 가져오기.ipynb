# %%
from urllib import request
from bs4 import BeautifulSoup

target = request.urlopen("http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108")
soup = BeautifulSoup(target, "html.parser")

for location in soup.select("location"):
    print("도시:", location.select_one("city").string)
    print("날씨:", location.select_one("wf").string)
    print("최저기온:", location.select_one("tmn").string)
    print("최고기온:", location.select_one("tmx").string)
    print()
# Out:
# 도시: 서울
# 날씨: 구름많음
# 최저기온: 18
# 최고기온: 28
#
# 도시: 인천
# 날씨: 구름많음
# 최저기온: 17
# 최고기온: 24
#
# 도시: 수원
# 날씨: 구름많음
# 최저기온: 16
# 최고기온: 28
#
# 도시: 파주
# 날씨: 구름많음
# 최저기온: 15
# 최고기온: 27
#
# 도시: 이천
# 날씨: 구름많음
# 최저기온: 16
# 최고기온: 29
#
# 도시: 평택
# 날씨: 구름많음
# 최저기온: 17
# 최고기온: 29
#
# 도시: 춘천
# 날씨: 구름많음
# 최저기온: 15
# 최고기온: 28
#
# 도시: 원주
# 날씨: 구름많음
# 최저기온: 16
# 최고기온: 28
#
# 도시: 강릉
# 날씨: 맑음
# 최저기온: 19
# 최고기온: 30
#
# 도시: 대전
# 날씨: 구름많음
# 최저기온: 17
# 최고기온: 28
#
# 도시: 세종
# 날씨: 구름많음
# 최저기온: 15
# 최고기온: 28
#
# 도시: 홍성
# 날씨: 구름많음
# 최저기온: 16
# 최고기온: 27
#
# 도시: 청주
# 날씨: 구름많음
# 최저기온: 18
# 최고기온: 29
#
# 도시: 충주
# 날씨: 구름많음
# 최저기온: 15
# 최고기온: 29
#
# 도시: 영동
# 날씨: 구름많음
# 최저기온: 13
# 최고기온: 28
#
# 도시: 광주
# 날씨: 구름많음
# 최저기온: 18
# 최고기온: 29
#
# 도시: 목포
# 날씨: 구름많음
# 최저기온: 18
# 최고기온: 25
#
# 도시: 여수
# 날씨: 구름많음
# 최저기온: 19
# 최고기온: 26
#
# 도시: 순천
# 날씨: 구름많음
# 최저기온: 17
# 최고기온: 29
#
# 도시: 광양
# 날씨: 구름많음
# 최저기온: 18
# 최고기온: 29
#
# 도시: 나주
# 날씨: 구름많음
# 최저기온: 16
# 최고기온: 28
#
# 도시: 전주
# 날씨: 구름많음
# 최저기온: 17
# 최고기온: 29
#
# 도시: 군산
# 날씨: 구름많음
# 최저기온: 17
# 최고기온: 26
#
# 도시: 정읍
# 날씨: 구름많음
# 최저기온: 17
# 최고기온: 28
#
# 도시: 남원
# 날씨: 구름많음
# 최저기온: 16
# 최고기온: 29
#
# 도시: 고창
# 날씨: 구름많음
# 최저기온: 16
# 최고기온: 27
#
# 도시: 무주
# 날씨: 구름많음
# 최저기온: 14
# 최고기온: 28
#
# 도시: 부산
# 날씨: 구름많음
# 최저기온: 18
# 최고기온: 25
#
# 도시: 울산
# 날씨: 구름많음
# 최저기온: 17
# 최고기온: 28
#
# 도시: 창원
# 날씨: 구름많음
# 최저기온: 17
# 최고기온: 28
#
# 도시: 진주
# 날씨: 구름많음
# 최저기온: 15
# 최고기온: 29
#
# 도시: 거창
# 날씨: 구름많음
# 최저기온: 13
# 최고기온: 29
#
# 도시: 통영
# 날씨: 구름많음
# 최저기온: 17
# 최고기온: 25
#
# 도시: 대구
# 날씨: 구름많음
# 최저기온: 18
# 최고기온: 30
#
# 도시: 안동
# 날씨: 구름많음
# 최저기온: 15
# 최고기온: 29
#
# 도시: 포항
# 날씨: 구름많음
# 최저기온: 19
# 최고기온: 29
#
# 도시: 경주
# 날씨: 구름많음
# 최저기온: 15
# 최고기온: 30
#
# 도시: 울진
# 날씨: 구름많음
# 최저기온: 17
# 최고기온: 25
#
# 도시: 울릉도
# 날씨: 구름많음
# 최저기온: 18
# 최고기온: 25
#
# 도시: 제주
# 날씨: 구름많음
# 최저기온: 18
# 최고기온: 26
#
# 도시: 서귀포
# 날씨: 구름많음
# 최저기온: 18
# 최고기온: 25
# c:\Users\caqud\AppData\Local\Programs\Python\Python311\Lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
